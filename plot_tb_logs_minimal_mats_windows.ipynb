# %%
import os
import pprint
import timeit
import copy
import multiprocessing
import re

import numpy as np
import matplotlib.pyplot as plt

from tensorboard.backend.event_processing.event_accumulator import EventAccumulator
from functools import reduce

# %% [markdown]
# # Load and parse Tensorboard logs

# %%
from joblib import delayed, Parallel
# Function to load tensorboard logs from one directory
def load_tensorboard_logs(subdir, parent_dir):
    # Create the full path to the subdirectory
    subdirectory_path = os.path.join(parent_dir, subdir)
    start_time = timeit.default_timer()
    
    # Load TensorBoard logs
    event_acc = EventAccumulator(subdirectory_path)
    event_acc.Reload()

    # Extract scalar values
    scalar_tags = event_acc.Tags()["scalars"]
    scalar_values = {}
    for tag in scalar_tags:
        events = event_acc.Scalars(tag)
        values = [(event.step, event.value) for event in events]
        scalar_values[tag] = values

    end_time = timeit.default_timer()
    iteration_time = end_time - start_time
    return (subdir, scalar_values, iteration_time)

def load_tensorboard_logs_mp(mp):
    return load_tensorboard_logs(*mp)

# Specify the parent directory containing directories with logs
parent_dir = r"C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr"
from pathlib import Path
print(Path(parent_dir).exists())

# Get a list of subdirectories in the parent directory
subdirectories = [subdir for subdir in os.listdir(parent_dir) if os.path.isdir(os.path.join(parent_dir, subdir))]

start_time = timeit.default_timer()
# Use a multiprocessing pool to load tensorboard logs in parallel
#with multiprocessing.get_context('spawn').Pool() as pool:
pool = Parallel(n_jobs=-1)
if True:
    total_time = 0
    result_dict = {}
    results = pool(delayed(load_tensorboard_logs_mp)((subdir, parent_dir)) for subdir in subdirectories)
    for subdir, scalar_values, iteration_time in results:
        result_dict[subdir] = scalar_values
        total_time += iteration_time
        print(f'Loaded {os.path.join(parent_dir, subdir)} in {iteration_time} seconds')

end_time = timeit.default_timer()
print("All loaded in {} Seconds".format(end_time - start_time))
# Out:
# True
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3145826_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch in 23.714577300000002 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3145828_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch in 25.081676 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3145830_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch in 24.4768285 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3145842_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch in 24.2477873 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3145845_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch in 23.4282101 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3145849_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch in 24.3827979 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3146028_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_resume in 24.7128227 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3146436_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch in 24.0441811 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3146441_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch in 23.7419815 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3146488_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch in 24.986113099999997 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3146549_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch in 26.988196600000002 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3147091_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch in 27.5784162 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3147695_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch in 27.785652900000002 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3148094_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch in 25.0960475 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3148650_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch in 24.076179699999997 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3149031_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch in 23.845556000000002 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3149302_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch in 24.3206271 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3149913_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch in 26.1739135 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3150303_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch in 27.5060937 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3150601_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch in 25.7035491 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3150994_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch in 10.729559900000002 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3151412_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch in 9.886294099999997 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3151764_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune in 12.902671899999998 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3151892_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch in 8.3852014 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3151972_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune in 10.089546200000001 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3152040_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune in 9.8978371 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3152044_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune in 10.047381400000003 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3152049_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune in 13.803696900000002 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3152374_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch in 12.180771799999999 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3152547_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune in 13.236011900000001 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3153002_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune in 13.3599797 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3153160_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune in 14.256579000000002 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3153366_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune in 13.2394861 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3153551_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune in 13.290237200000004 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3153606_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune in 13.452496699999998 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3153675_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune in 13.2592632 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3153700_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune in 13.763247000000003 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3153758_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune in 13.3876524 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3153784_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune in 11.561773500000001 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3153886_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune in 13.041565500000004 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3153945_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune in 10.376963199999999 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3154168_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune in 14.0237257 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3154310_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune in 10.803512900000001 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3154434_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune in 13.565294699999995 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3154595_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune in 10.852180599999997 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3154803_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune in 13.337123900000002 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3154929_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune in 10.7312413 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3154971_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune in 11.008781300000003 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3155005_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune in 10.588635200000006 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3155155_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune in 10.652733900000001 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3155209_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune in 10.576042800000003 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3155285_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune in 10.604731399999999 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3155369_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune in 10.5885356 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3155428_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune in 10.387968300000004 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3155539_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune in 10.538349100000005 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3155709_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune in 10.549114800000005 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3155710_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune in 10.681845500000001 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3155852_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_finetune in 14.660105699999995 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3155852_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch in 14.710237200000002 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3156024_410M_it-132366_wu-0.01_mxlr-0.0006_mnlr-6e-05_sch-cosine_tr-slim-pajama-300B_finetune in 15.2308977 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3156581_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_finetune in 13.743732099999995 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3156583_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch in 15.107312899999997 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3156632_410M_it-132366_wu-0.01_mxlr-0.0006_mnlr-6e-05_sch-cosine_tr-slim-pajama-300B_finetune in 14.019607700000002 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3156799_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_finetune in 14.887751899999998 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3156865_410M_it-132366_wu-0.01_mxlr-0.0006_mnlr-6e-05_sch-cosine_tr-slim-pajama-300B_finetune in 14.9047616 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3156960_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_finetune in 15.001038699999995 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3156964_410M_it-132366_wu-0.01_mxlr-0.0006_mnlr-6e-05_sch-cosine_tr-slim-pajama-300B_finetune in 14.123857000000001 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3157025_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch in 13.725908099999998 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3157307_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch in 14.902677600000004 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3157308_410M_it-132366_wu-0.01_mxlr-0.0006_mnlr-6e-05_sch-cosine_tr-slim-pajama-300B_finetune in 13.977602100000006 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3157309_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_finetune in 14.429759100000005 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3157497_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch in 12.2456235 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3157519_410M_it-132366_wu-0.01_mxlr-0.0006_mnlr-6e-05_sch-cosine_tr-slim-pajama-300B_finetune in 12.760094600000002 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3157524_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_finetune in 12.403970299999997 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3157606_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch in 14.123196500000006 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3157751_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_finetune in 14.640709199999996 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3158050_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch in 11.128580900000003 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3158153_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_finetune in 13.612243099999993 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3158372_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch in 13.512113699999993 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3158621_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_finetune in 11.1861325 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3159039_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch in 13.603056999999993 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3159040_410M_it-132366_wu-0.01_mxlr-0.0006_mnlr-6e-05_sch-cosine_tr-slim-pajama-300B_finetune in 13.310160399999994 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3159173_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch in 12.636373200000008 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3159174_410M_it-132366_wu-0.01_mxlr-0.0006_mnlr-6e-05_sch-cosine_tr-slim-pajama-300B_finetune in 11.682875899999992 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3159529_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch in 12.028077999999994 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3160197_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch in 10.874020700000003 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3160758_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch in 9.8791875 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3161364_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch in 9.919433099999992 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3161610_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch in 9.8434447 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3161852_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch in 9.729922200000004 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3162468_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch in 9.780612599999998 seconds
# Loaded C:\Users\matsl\Documents\tensorboard\tensorboard\cpt_iclr\JOB-3163457_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch in 9.7131026 seconds
# All loaded in 75.1714885 Seconds

# %%
from tqdm import tqdm
# remove empty
for x in [k for k,v in tqdm(result_dict.items()) if v == {}]:
    print(x)
    result_dict.pop(x)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 92/92 [00:00<?, ?it/s]
# JOB-3145826_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch
# JOB-3145828_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch
# JOB-3145830_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch
# JOB-3145842_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch
# JOB-3145845_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch
# JOB-3146436_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch
# JOB-3146441_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch
# JOB-3146488_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch
# JOB-3148650_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch
# JOB-3151892_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch
# JOB-3152040_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune
# JOB-3152044_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune

# %% [markdown]
# ## Loaded TB directories:

# %%
pprint.pprint(list(result_dict.keys()))
# Out:
# ['JOB-3145849_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch',
#  'JOB-3146028_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_resume',
#  'JOB-3146549_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch',
#  'JOB-3147091_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch',
#  'JOB-3147695_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch',
#  'JOB-3148094_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch',
#  'JOB-3149031_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch',
#  'JOB-3149302_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch',
#  'JOB-3149913_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch',
#  'JOB-3150303_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch',
#  'JOB-3150601_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch',
#  'JOB-3150994_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch',
#  'JOB-3151412_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch',
#  'JOB-3151764_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3151972_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3152049_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3152374_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch',
#  'JOB-3152547_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3153002_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3153160_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3153366_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3153551_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3153606_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3153675_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3153700_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3153758_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3153784_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3153886_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3153945_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3154168_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3154310_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3154434_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3154595_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3154803_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3154929_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3154971_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3155005_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3155155_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3155209_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3155285_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3155369_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3155428_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3155539_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3155709_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3155710_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3155852_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3155852_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3156024_410M_it-132366_wu-0.01_mxlr-0.0006_mnlr-6e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3156581_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3156583_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3156632_410M_it-132366_wu-0.01_mxlr-0.0006_mnlr-6e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3156799_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3156865_410M_it-132366_wu-0.01_mxlr-0.0006_mnlr-6e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3156960_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3156964_410M_it-132366_wu-0.01_mxlr-0.0006_mnlr-6e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3157025_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3157307_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3157308_410M_it-132366_wu-0.01_mxlr-0.0006_mnlr-6e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3157309_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3157497_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3157519_410M_it-132366_wu-0.01_mxlr-0.0006_mnlr-6e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3157524_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3157606_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3157751_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3158050_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3158153_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3158372_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3158621_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3159039_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3159040_410M_it-132366_wu-0.01_mxlr-0.0006_mnlr-6e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3159173_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3159174_410M_it-132366_wu-0.01_mxlr-0.0006_mnlr-6e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3159529_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3160197_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3160758_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3161364_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3161610_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3161852_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3162468_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3163457_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch']

# %% [markdown]
# # Parse Job Info from name

# %%
def parse_job_string(job_string):
    # Regular expression pattern for each parameter
    patterns = {
        "Model": r"JOB-\d+_([\d.-]+B)_",    # Look for the model size format e.g., 7.1B
        "It": r"it-(\d+)",        # Look for the iterations number
        "WU": r"wu-([\d.]+)",
        "MaxLR": r"mxlr-([\d.e-]+)",
        "MinLR": r"mnlr-([\d.e-]+)",
        "Sch": r"sch-([\w]+)_",   # Adjusted the regex
        "Tr": r"tr-([\w-]+)_",  # Extract training dataset
        "Postfix": r"(finetune|resume|scratch)$",
    }

    result = ""
    for key in patterns:
        match = re.search(patterns[key], job_string)
        if match:
            if key == "MaxLR":
                # Convert to float and format as scientific notation
                value = "{:e}".format(float(match.group(1)))
                idx = len(value.split('e')[0])
                value = value[:idx].rstrip('0').rstrip('.') + value[idx:]
            else:
                value = match.group(1)
            result += f"{key}={value} "
            
    #result += job_string.split("_")[-1]
    return result.rstrip()  # remove trailing space

input_str = 'JOB-3152028_7-1B_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch'
print(parse_job_string(input_str))
# Out:
# Model=7-1B It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=pile-train Postfix=scratch

# %%
#pprint.pprint(list(result_dict.keys()))

# %%
#accumulate tb log files by job name
d = {}
for k,v in result_dict.items():
    try:
        d[parse_job_string(k)][k] = v
    except KeyError:
        d[parse_job_string(k)] = {k:v}

# %%
#accumulate tb log files by job name
#d = {}
#for k,v in result_dict.items():
#    try:
#        d[k.split("410M_")[-1]][k] = v
#    except KeyError:
#       d[k.split("410M_")[-1]] = {k:v}

# %%
pprint.pprint(list(d.keys()))
# Out:
# ['It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=pile-train '
#  'Postfix=scratch',
#  'It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=pile-train '
#  'Postfix=resume',
#  'It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B '
#  'Postfix=finetune',
#  'It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B '
#  'Postfix=finetune',
#  'It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B '
#  'Postfix=finetune',
#  'It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B '
#  'Postfix=scratch',
#  'It=132366 WU=0.01 MaxLR=6e-04 MinLR=6e-05 Sch=cosine Tr=slim-pajama-300B '
#  'Postfix=finetune']

# %%
for key in d.keys():
    pprint.pprint(list(d[key].keys()))
# Out:
# ['JOB-3145849_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch',
#  'JOB-3146549_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch',
#  'JOB-3147091_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch',
#  'JOB-3147695_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch',
#  'JOB-3148094_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch',
#  'JOB-3149031_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch',
#  'JOB-3149302_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch',
#  'JOB-3149913_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch',
#  'JOB-3150303_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch',
#  'JOB-3150601_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch',
#  'JOB-3150994_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch',
#  'JOB-3151412_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch',
#  'JOB-3152374_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_scratch']
# ['JOB-3146028_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-pile-train_resume']
# ['JOB-3151764_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3151972_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3152049_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3152547_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3153002_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3153366_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3153606_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3153700_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3153784_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3153945_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3154310_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3154595_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3154929_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3155005_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3155209_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3155369_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3155539_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune',
#  'JOB-3155710_410M_it-132366_wu-0.0_mxlr-3e-05_mnlr-3e-05_sch-constant_tr-slim-pajama-300B_finetune']
# ['JOB-3153160_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3153551_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3153675_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3153758_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3153886_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3154168_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3154434_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3154803_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3154971_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3155155_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3155285_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3155428_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3155709_410M_it-132366_wu-0.01_mxlr-0.00015_mnlr-1.5e-05_sch-cosine_tr-slim-pajama-300B_finetune']
# ['JOB-3155852_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3156581_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3156799_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3156960_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3157309_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3157524_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3157751_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3158153_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3158621_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_finetune']
# ['JOB-3155852_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3156583_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3157025_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3157307_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3157497_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3157606_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3158050_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3158372_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3159039_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3159173_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3159529_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3160197_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3160758_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3161364_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3161610_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3161852_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3162468_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch',
#  'JOB-3163457_410M_it-132366_wu-0.01_mxlr-0.0003_mnlr-3e-05_sch-cosine_tr-slim-pajama-300B_scratch']
# ['JOB-3156024_410M_it-132366_wu-0.01_mxlr-0.0006_mnlr-6e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3156632_410M_it-132366_wu-0.01_mxlr-0.0006_mnlr-6e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3156865_410M_it-132366_wu-0.01_mxlr-0.0006_mnlr-6e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3156964_410M_it-132366_wu-0.01_mxlr-0.0006_mnlr-6e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3157308_410M_it-132366_wu-0.01_mxlr-0.0006_mnlr-6e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3157519_410M_it-132366_wu-0.01_mxlr-0.0006_mnlr-6e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3159040_410M_it-132366_wu-0.01_mxlr-0.0006_mnlr-6e-05_sch-cosine_tr-slim-pajama-300B_finetune',
#  'JOB-3159174_410M_it-132366_wu-0.01_mxlr-0.0006_mnlr-6e-05_sch-cosine_tr-slim-pajama-300B_finetune']

# %% [markdown]
# # Merge Tensorboard logs into a single ordered sequence per run (a run can be many jobs)

# %%
def merge_tb_logs(list_dict):
    for k,v in list_dict.items():
        if len(v) > 1:
            temp = sorted(list(v.keys()),key=lambda x:int(x[4:11]))
            accum = {kk:dict(vv) for kk,vv in v[temp[0]].items()}
            
            
            for x in temp[1:]:
                for kk,vv in accum.items():
                        try:
                            accum[kk].update(dict(v[x][kk]))
                        except KeyError as e:
                            print(e)
                            print("Missing key:",kk)
                            print("Outer key:",k)

            #sort the zipped object
            list_dict[k] = {kk:sorted([x for x in zip(tmp.keys(),tmp.values())], key=lambda x: x[0]) for kk,tmp in accum.items()}
        else:
            list_dict[k] = list(v.values())[0]
            
    return list_dict


rd_clone = merge_tb_logs(copy.deepcopy(d))
# Out:
# 'train/learning_rate'
# Missing key: train/learning_rate
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=pile-train Postfix=scratch
# 'train/lm_loss'
# Missing key: train/lm_loss
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=pile-train Postfix=scratch
# 'train/loss_scale'
# Missing key: train/loss_scale
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=pile-train Postfix=scratch
# 'runtime/samples_per_sec'
# Missing key: runtime/samples_per_sec
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=pile-train Postfix=scratch
# 'runtime/iteration_time'
# Missing key: runtime/iteration_time
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=pile-train Postfix=scratch
# 'runtime/flops_per_sec_per_gpu'
# Missing key: runtime/flops_per_sec_per_gpu
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=pile-train Postfix=scratch
# 'train/learning_rate'
# Missing key: train/learning_rate
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'train/lm_loss'
# Missing key: train/lm_loss
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'train/loss_scale'
# Missing key: train/loss_scale
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'runtime/samples_per_sec'
# Missing key: runtime/samples_per_sec
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'runtime/iteration_time'
# Missing key: runtime/iteration_time
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'runtime/flops_per_sec_per_gpu'
# Missing key: runtime/flops_per_sec_per_gpu
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'train/learning_rate'
# Missing key: train/learning_rate
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'train/lm_loss'
# Missing key: train/lm_loss
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'train/loss_scale'
# Missing key: train/loss_scale
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'runtime/samples_per_sec'
# Missing key: runtime/samples_per_sec
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'runtime/iteration_time'
# Missing key: runtime/iteration_time
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'runtime/flops_per_sec_per_gpu'
# Missing key: runtime/flops_per_sec_per_gpu
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'train/learning_rate'
# Missing key: train/learning_rate
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'train/lm_loss'
# Missing key: train/lm_loss
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'train/loss_scale'
# Missing key: train/loss_scale
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'runtime/samples_per_sec'
# Missing key: runtime/samples_per_sec
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'runtime/iteration_time'
# Missing key: runtime/iteration_time
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'runtime/flops_per_sec_per_gpu'
# Missing key: runtime/flops_per_sec_per_gpu
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'train/learning_rate'
# Missing key: train/learning_rate
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'train/lm_loss'
# Missing key: train/lm_loss
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'train/loss_scale'
# Missing key: train/loss_scale
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'runtime/samples_per_sec'
# Missing key: runtime/samples_per_sec
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'runtime/iteration_time'
# Missing key: runtime/iteration_time
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'runtime/flops_per_sec_per_gpu'
# Missing key: runtime/flops_per_sec_per_gpu
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'train/learning_rate'
# Missing key: train/learning_rate
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'train/lm_loss'
# Missing key: train/lm_loss
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'train/loss_scale'
# Missing key: train/loss_scale
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'runtime/samples_per_sec'
# Missing key: runtime/samples_per_sec
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'runtime/iteration_time'
# Missing key: runtime/iteration_time
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'runtime/flops_per_sec_per_gpu'
# Missing key: runtime/flops_per_sec_per_gpu
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'train/learning_rate'
# Missing key: train/learning_rate
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'train/lm_loss'
# Missing key: train/lm_loss
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'train/loss_scale'
# Missing key: train/loss_scale
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'runtime/samples_per_sec'
# Missing key: runtime/samples_per_sec
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'runtime/iteration_time'
# Missing key: runtime/iteration_time
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'runtime/flops_per_sec_per_gpu'
# Missing key: runtime/flops_per_sec_per_gpu
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'train/learning_rate'
# Missing key: train/learning_rate
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'train/lm_loss'
# Missing key: train/lm_loss
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'train/loss_scale'
# Missing key: train/loss_scale
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'runtime/samples_per_sec'
# Missing key: runtime/samples_per_sec
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'runtime/iteration_time'
# Missing key: runtime/iteration_time
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'runtime/flops_per_sec_per_gpu'
# Missing key: runtime/flops_per_sec_per_gpu
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'train/learning_rate'
# Missing key: train/learning_rate
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'train/lm_loss'
# Missing key: train/lm_loss
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'train/loss_scale'
# Missing key: train/loss_scale
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'runtime/samples_per_sec'
# Missing key: runtime/samples_per_sec
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'runtime/iteration_time'
# Missing key: runtime/iteration_time
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'runtime/flops_per_sec_per_gpu'
# Missing key: runtime/flops_per_sec_per_gpu
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'train/learning_rate'
# Missing key: train/learning_rate
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'train/lm_loss'
# Missing key: train/lm_loss
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'train/loss_scale'
# Missing key: train/loss_scale
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'runtime/samples_per_sec'
# Missing key: runtime/samples_per_sec
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'runtime/iteration_time'
# Missing key: runtime/iteration_time
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'runtime/flops_per_sec_per_gpu'
# Missing key: runtime/flops_per_sec_per_gpu
# Outer key: It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 'train/learning_rate'
# Missing key: train/learning_rate
# Outer key: It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'train/lm_loss'
# Missing key: train/lm_loss
# Outer key: It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'train/loss_scale'
# Missing key: train/loss_scale
# Outer key: It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'runtime/samples_per_sec'
# Missing key: runtime/samples_per_sec
# Outer key: It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'runtime/iteration_time'
# Missing key: runtime/iteration_time
# Outer key: It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'runtime/flops_per_sec_per_gpu'
# Missing key: runtime/flops_per_sec_per_gpu
# Outer key: It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'train/learning_rate'
# Missing key: train/learning_rate
# Outer key: It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'train/lm_loss'
# Missing key: train/lm_loss
# Outer key: It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'train/loss_scale'
# Missing key: train/loss_scale
# Outer key: It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'runtime/samples_per_sec'
# Missing key: runtime/samples_per_sec
# Outer key: It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'runtime/iteration_time'
# Missing key: runtime/iteration_time
# Outer key: It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'runtime/flops_per_sec_per_gpu'
# Missing key: runtime/flops_per_sec_per_gpu
# Outer key: It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'train/learning_rate'
# Missing key: train/learning_rate
# Outer key: It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'train/lm_loss'
# Missing key: train/lm_loss
# Outer key: It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'train/loss_scale'
# Missing key: train/loss_scale
# Outer key: It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'runtime/samples_per_sec'
# Missing key: runtime/samples_per_sec
# Outer key: It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'runtime/iteration_time'
# Missing key: runtime/iteration_time
# Outer key: It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'runtime/flops_per_sec_per_gpu'
# Missing key: runtime/flops_per_sec_per_gpu
# Outer key: It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'train/learning_rate'
# Missing key: train/learning_rate
# Outer key: It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'train/lm_loss'
# Missing key: train/lm_loss
# Outer key: It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'train/loss_scale'
# Missing key: train/loss_scale
# Outer key: It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'runtime/samples_per_sec'
# Missing key: runtime/samples_per_sec
# Outer key: It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'runtime/iteration_time'
# Missing key: runtime/iteration_time
# Outer key: It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'runtime/flops_per_sec_per_gpu'
# Missing key: runtime/flops_per_sec_per_gpu
# Outer key: It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'train/learning_rate'
# Missing key: train/learning_rate
# Outer key: It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'train/lm_loss'
# Missing key: train/lm_loss
# Outer key: It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'train/loss_scale'
# Missing key: train/loss_scale
# Outer key: It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'runtime/samples_per_sec'
# Missing key: runtime/samples_per_sec
# Outer key: It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'runtime/iteration_time'
# Missing key: runtime/iteration_time
# Outer key: It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'runtime/flops_per_sec_per_gpu'
# Missing key: runtime/flops_per_sec_per_gpu
# Outer key: It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'train/learning_rate'
# Missing key: train/learning_rate
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'train/lm_loss'
# Missing key: train/lm_loss
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'train/loss_scale'
# Missing key: train/loss_scale
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'runtime/samples_per_sec'
# Missing key: runtime/samples_per_sec
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'runtime/iteration_time'
# Missing key: runtime/iteration_time
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'runtime/flops_per_sec_per_gpu'
# Missing key: runtime/flops_per_sec_per_gpu
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 'train/learning_rate'
# Missing key: train/learning_rate
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'train/lm_loss'
# Missing key: train/lm_loss
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'train/loss_scale'
# Missing key: train/loss_scale
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'runtime/samples_per_sec'
# Missing key: runtime/samples_per_sec
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'runtime/iteration_time'
# Missing key: runtime/iteration_time
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'runtime/flops_per_sec_per_gpu'
# Missing key: runtime/flops_per_sec_per_gpu
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'train/learning_rate'
# Missing key: train/learning_rate
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'train/lm_loss'
# Missing key: train/lm_loss
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'train/loss_scale'
# Missing key: train/loss_scale
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'runtime/samples_per_sec'
# Missing key: runtime/samples_per_sec
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'runtime/iteration_time'
# Missing key: runtime/iteration_time
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'runtime/flops_per_sec_per_gpu'
# Missing key: runtime/flops_per_sec_per_gpu
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'train/learning_rate'
# Missing key: train/learning_rate
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'train/lm_loss'
# Missing key: train/lm_loss
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'train/loss_scale'
# Missing key: train/loss_scale
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'runtime/samples_per_sec'
# Missing key: runtime/samples_per_sec
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'runtime/iteration_time'
# Missing key: runtime/iteration_time
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'runtime/flops_per_sec_per_gpu'
# Missing key: runtime/flops_per_sec_per_gpu
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'train/learning_rate'
# Missing key: train/learning_rate
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'train/lm_loss'
# Missing key: train/lm_loss
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'train/loss_scale'
# Missing key: train/loss_scale
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'runtime/samples_per_sec'
# Missing key: runtime/samples_per_sec
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'runtime/iteration_time'
# Missing key: runtime/iteration_time
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'runtime/flops_per_sec_per_gpu'
# Missing key: runtime/flops_per_sec_per_gpu
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'train/learning_rate'
# Missing key: train/learning_rate
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'train/lm_loss'
# Missing key: train/lm_loss
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'train/loss_scale'
# Missing key: train/loss_scale
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'runtime/samples_per_sec'
# Missing key: runtime/samples_per_sec
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'runtime/iteration_time'
# Missing key: runtime/iteration_time
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'runtime/flops_per_sec_per_gpu'
# Missing key: runtime/flops_per_sec_per_gpu
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'train/learning_rate'
# Missing key: train/learning_rate
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'train/lm_loss'
# Missing key: train/lm_loss
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'train/loss_scale'
# Missing key: train/loss_scale
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'runtime/samples_per_sec'
# Missing key: runtime/samples_per_sec
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'runtime/iteration_time'
# Missing key: runtime/iteration_time
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'runtime/flops_per_sec_per_gpu'
# Missing key: runtime/flops_per_sec_per_gpu
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'train/learning_rate'
# Missing key: train/learning_rate
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'train/lm_loss'
# Missing key: train/lm_loss
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'train/loss_scale'
# Missing key: train/loss_scale
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'runtime/samples_per_sec'
# Missing key: runtime/samples_per_sec
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'runtime/iteration_time'
# Missing key: runtime/iteration_time
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 'runtime/flops_per_sec_per_gpu'
# Missing key: runtime/flops_per_sec_per_gpu
# Outer key: It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch

# %%
def get_caption(key,use=dict(mx=True,wu=True,mn=True,ds=True,it=True,sh=True)):
    temp = key.split(' ')
    out = ''
    print(temp)
    
    #FIXME: FIX THIS
    if use["sh"]:
        out += f"{'Cosine ' if 'cosine' in key else 'Constant LR '}"
    
    if key in ['WU=0.0 MaxLR=3e-05 MinLR=3e-05 RP','WU=0.0 MaxLR=3e-05 MinLR=3e-05 Pile']:
        out = 'Constant 3e-05'
        
        
        
        if use['it']:
            if temp[3].endswith('10000'):
                out += "Iter. 10000"
            elif temp[3].endswith('27000'):
                out += "Iter. 27000"
            elif 'scratch' in key:
                out += "Iter. 0"
            else:
                out += "Iter. 143000"
        
        return out
    
    
    
        
    if use['mx']:
        out += temp[1].replace("="," ") + " "
    
    if use['mn']:
        out += temp[2].replace("="," ") + " "
        
    
    
    print(temp)
    if use['ds']:
        if "RP" in temp[5]:
            out += 'RP' + " "
        elif 'slim' in temp[5]:
            out += 'SP' + " "
        else: 
            out += 'Pile' + " "
        
    # if use['it']:
    #     if temp[3].endswith('10000'):
    #         out += "Iter. 10000"
    #     elif temp[3].endswith('27000'):
    #         out += "Iter. 27000"
    #     elif 'scratch' in key:
    #         out += "Iter. 0"
    #     else:
    #         out += "Iter. 143000"
            
            
    #if use['it']:
    #    out += temp[6]
    
    
    if "Constant" in out:
        out = out.replace('MaxLR ', " ")
        
    if use['wu']:
        print("WU")
        if 'scratch' in key:
            out += "Iter. 0"
        else: 
            out += temp[0].replace("="," ") + " "
        
    if "It " in out:
        out = out.replace("It ", "Iter. ")
    
            
        
    return out.strip(' ')
    
get_caption('It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune',use=dict(mx=False,wu=True,mn=True,ds=False,it=False, sh=True))
# Out:
# ['It=132366', 'WU=0.0', 'MaxLR=3e-05', 'MinLR=3e-05', 'Sch=constant', 'Tr=slim-pajama-300B', 'Postfix=finetune']
# ['It=132366', 'WU=0.0', 'MaxLR=3e-05', 'MinLR=3e-05', 'Sch=constant', 'Tr=slim-pajama-300B', 'Postfix=finetune']
# WU
# 'Constant LR  3e-05 Iter. 132366'

# %%
{x:get_caption(x,use=dict(mx=False,wu=True,mn=False,ds=False,it=False, sh=True)) for x in rd_clone.keys()}
# Out:
# ['It=132366', 'WU=0.0', 'MaxLR=3e-05', 'MinLR=3e-05', 'Sch=constant', 'Tr=slim-pajama-300B', 'Postfix=finetune']
# WU
# ['It=132366', 'WU=0.0', 'MaxLR=3e-05', 'MinLR=3e-05', 'Sch=constant', 'Tr=slim-pajama-300B', 'Postfix=finetune']
# ['It=132366', 'WU=0.01', 'MaxLR=1.5e-04', 'MinLR=1.5e-05', 'Sch=cosine', 'Tr=slim-pajama-300B', 'Postfix=finetune']
# WU
# ['It=132366', 'WU=0.01', 'MaxLR=1.5e-04', 'MinLR=1.5e-05', 'Sch=cosine', 'Tr=slim-pajama-300B', 'Postfix=finetune']
# ['It=132366', 'WU=0.01', 'MaxLR=3e-04', 'MinLR=3e-05', 'Sch=cosine', 'Tr=pile-train', 'Postfix=scratch']
# WU
# ['It=132366', 'WU=0.01', 'MaxLR=3e-04', 'MinLR=3e-05', 'Sch=cosine', 'Tr=pile-train', 'Postfix=scratch']
# ['It=132366', 'WU=0.01', 'MaxLR=3e-04', 'MinLR=3e-05', 'Sch=cosine', 'Tr=pile-train', 'Postfix=resume']
# WU
# ['It=132366', 'WU=0.01', 'MaxLR=3e-04', 'MinLR=3e-05', 'Sch=cosine', 'Tr=pile-train', 'Postfix=resume']
# ['It=132366', 'WU=0.01', 'MaxLR=3e-04', 'MinLR=3e-05', 'Sch=cosine', 'Tr=slim-pajama-300B', 'Postfix=finetune']
# WU
# ['It=132366', 'WU=0.01', 'MaxLR=3e-04', 'MinLR=3e-05', 'Sch=cosine', 'Tr=slim-pajama-300B', 'Postfix=finetune']
# ['It=132366', 'WU=0.01', 'MaxLR=3e-04', 'MinLR=3e-05', 'Sch=cosine', 'Tr=slim-pajama-300B', 'Postfix=scratch']
# WU
# ['It=132366', 'WU=0.01', 'MaxLR=3e-04', 'MinLR=3e-05', 'Sch=cosine', 'Tr=slim-pajama-300B', 'Postfix=scratch']
# ['It=132366', 'WU=0.01', 'MaxLR=6e-04', 'MinLR=6e-05', 'Sch=cosine', 'Tr=slim-pajama-300B', 'Postfix=finetune']
# WU
# ['It=132366', 'WU=0.01', 'MaxLR=6e-04', 'MinLR=6e-05', 'Sch=cosine', 'Tr=slim-pajama-300B', 'Postfix=finetune']
# {'It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune': 'It 132366 Constant',
#  'It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune': 'It 132366 Cosine',
#  'It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=pile-train Postfix=scratch': 'It 132366 Cosine',
#  'It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=pile-train Postfix=resume': 'It 132366 Cosine',
#  'It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune': 'It 132366 Cosine',
#  'It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch': 'It 132366 Cosine',
#  'It=132366 WU=0.01 MaxLR=6e-04 MinLR=6e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune': 'It 132366 Cosine'}

# %% [markdown]
# # Setup plotting vars

# %%
plt.rcParams['figure.dpi'] = 300 
step_to_token = lambda x : x * 2260992/1000000000

fontdict = {'family': 'serif',
#              'color':  'black',
             'weight': 'normal',
             'size': 12,}

plt.rc('font', **fontdict)

legend_font = {'family': 'serif',
                     'color':  'black',
                     'weight': 'normal',
                     'size': 12,}

colors = [
    "#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", 
    "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf", 
    "#aec7e8", "#ffbb78", "#98df8a", "#ff9896", "#c5b0d5", 
    "#c49c94", "#f7b6d2", "#c7c7c7", "#dbdb8d", "#9edae5", 
    "#393b79", "#637939", "#8c6d31", "#843c39", "#7b4173", 
    "#5254a3", "#636363", "#8ca252", "#bd9e39", "#ad494a", 
    "#8c6d31", "#393b79", "#637939", "#843c39", "#7b4173", 
    "#5254a3", "#636363", "#8ca252", "#bd9e39", "#ad494a", 
    "#bd9e39", "#ad494a", "#393b79", "#637939", "#8c6d31", 
    "#843c39", "#7b4173", "#5254a3", "#636363", "#8ca252", 
    "#bd9e39", "#ad494a", "#8c6d31", "#843c39", "#7b4173", 
    "#5254a3", "#636363", "#8ca252", "#bd9e39", "#ad494a", 
    "#8c6d31", "#843c39", "#7b4173", "#5254a3", "#636363", 
]

cp1 = ['darkred','black','darkblue','darkorange','darkviolet','darkgreen']
cp2 = ["#ee4035","#f37736","#fdf498","#7bc043","#0392cf"]
cp3 = ['#4b3832','#854442','#fff4e6','#3c2f2f','#be9b7b']

key_to_plot = 'validation/val_0/lm_loss' #pile
key_to_plot = 'validation/val_1/lm_loss' #RP

# %% [markdown]
# import re
#
# def parse_params(input_string, param_name):
#     # Regular expression pattern to find "PARAM=value" patterns.
#     # We use re.escape to ensure that any special characters in the parameter name
#     # are treated as literal characters in the regex pattern.
#     pattern = re.compile(r"{}=(-?\d+.?\d*(?:e-?\d+)?)".format(re.escape(param_name)))
#
#     # Find all matches in the input string and parse them into a list of floats
#     param_values = []
#     for match in re.finditer(pattern, input_string):
#         # Extract value from the match and convert to float, then add to list
#         param_values.append(float(match.group(1)))
#
#     return param_values
#
# # Example usage:
# input_string = "SOME_TEXT param1=3e4 ANOTHER_TEXT param2=1.23e-4 YET_ANOTHER_TEXT param3=42"
# param_name = input("Please enter the parameter name to search for: ")
#
# # Find and output param values
# param_values = parse_params(input_string, param_name)
# print("Values found for {}: {}".format(param_name, param_values))
# # Sort data

# %%
import re

def parse_params(input_string, param_name):
    # Regular expression pattern to find "PARAM=value" patterns.
    # We use re.escape to ensure that any special characters in the parameter name
    # are treated as literal characters in the regex pattern.
    pattern = re.compile(r"{}=(-?\d*\.?\d+(?:e-?\d+)?)".format(re.escape(param_name)), re.IGNORECASE)
    
    # Find all matches in the input string and parse them into a list of floats
    param_values = []
    for match in re.finditer(pattern, input_string):
        # Extract value from the match and convert to float, then add to list
        param_values.append(float(match.group(1)))
    
    # Check if there are any found values and return the first one if so
    return param_values[0] if param_values else None

# Example usage:
#input_string = "SOME_TEXT MaxLR=3e-4 ANOTHER_TEXT param2=1.23e-4 YET_ANOTHER_TEXT param3=42"
#param_name = input("Please enter the parameter name to search for: ")

# Find and output param values
#param_values = parse_params(input_string, param_name)
#print("Values found for {}: {}".format(param_name, param_values))

# %%
print(rd_clone.keys())
rd_clone = dict(sorted(rd_clone.items(), key=lambda x: parse_params(x[0], "WU")))
rd_clone = dict(sorted(rd_clone.items(), key=lambda x: parse_params(x[0], "MaxLR")))

#rd_clone = dict(sorted(rd_clone.items(), key=lambda x: float(x[0].split(' ')[3][len('MaxLR='):])))

#rd_clone = dict(sorted(rd_clone.items(), key=lambda x: float(x[0].split(' ')[2][len('WU='):])))
#rd_clone = dict(sorted(rd_clone.items(), key=lambda x: float(x[0].split(' ')[3][len('MaxLR='):])))
# Out:
# dict_keys(['It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune', 'It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune', 'It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=pile-train Postfix=scratch', 'It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=pile-train Postfix=resume', 'It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune', 'It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch', 'It=132366 WU=0.01 MaxLR=6e-04 MinLR=6e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune'])

# %% [markdown]
# # Plotting function  -- Here is where the magic happens

# %%
def plot_single(filter_=['Pile','MaxLR=1.5e-04','MaxLR=6e-04','MaxLR=3e-05',
                         '27000','10000'],
                upper_limit=50,
                key_to_plot='validation/val_0/lm_loss',
                ylabel='Tokens (B)',
                xlabel='Pile Val Loss',
                savepath=None, #"lr3e-4-Pile-val-loss-warmup-50B.pdf",
                legend_kwargs=dict(fontsize=12),
                ylim=[],#(2.18,2.55),
                figsize=(7.5,5),
                warmup_end={'0.01':True,'0.02':True,'0.005':True},
                savedir='esfomows/',
                color_dict={},
                ls_dict={},
                circles=False,
                default_colors=colors,
                default_ls =['-' for x in range(100)],
                label_dict={}
               ):
    data_dict = copy.deepcopy(rd_clone)
    # data_dict = dict(sorted(data_dict.items(), key=lambda x: float(label_dict.get(x[0],x[0]).split('=')[-1])))
                   
    fig, ax = plt.subplots(1,1,figsize=figsize)
    ii=0
    for i,(k,v) in enumerate(data_dict.items()):
        print(i, k)
        if len(v) == 0 \
           or reduce(np.logical_or,[x in k for x in filter_]):
            continue #skip
            
        
            
        # print(f"\"{k}\":")

        temp = np.array(v[key_to_plot])
        
        iters_ = step_to_token(temp[:,0])
        value_ = temp[:,1]
        w = np.where(iters_ < upper_limit)

        # print(np.min(temp[np.where(temp[:,1] == 1e-5),0]))print()print

        # print(k) 

            
        # print(value_,len(value_))
        # value_ = moving_average(value_,10)
        # print(value_,len(value_))
        ax.plot(iters_[w[0]],
                value_[w[0]],
                label=label_dict.get(k,k),
                linewidth=0.9,
                color=color_dict.get(k,default_colors[ii]),
                linestyle=ls_dict.get(k,default_ls[ii]))
        
        ax.set_xlabel(ylabel,)
        ax.set_ylabel(xlabel,)
    
        ii+=1
        
    vertical_bar = []
    for i,(k,v) in enumerate(data_dict.items()):  
        if len(v) == 0 or reduce(np.logical_or,[x in k for x in filter_]):
            continue
        v0 = np.array(v[key_to_plot]) #red pajama
        w = np.where(np.logical_and(1818 < v0[:,0],
                                    v0[:,0] < 1826,))
        
#         print(v0[w,0],v0[w,1])
        vertical_bar.append(step_to_token(v0[w,0]))

    # 662, 1318, 2633
    if warmup_end['0.005']:
        ax.axvline(x=step_to_token(662), color='lightgray', linestyle='-.',linewidth=0.5)
    if warmup_end['0.01']:
        ax.axvline(x=step_to_token(1318), color='lightgray', linestyle='-.',linewidth=0.5)
    if warmup_end['0.02']:
        ax.axvline(x=step_to_token(2633), color='lightgray', linestyle='-.',linewidth=0.5)
        
    if circles:
        x = [10,24,48]
        y = [2.58,2.5,2.445]
        plt.plot(x, y, 
                 marker='o', 
                 color='red', 
                 fillstyle='none', 
                 linestyle='None',
                 markersize=25,
                linewidth=15)  # Hollow red circles
        
#     for spine in ['left', 'right', 'bottom', 'top']:
#         ax.spines[spine].set_color('lightgrey')

    ax.legend(**legend_kwargs)
    ax.set_ylim(*ylim)
    if savepath:
        plt.savefig(savedir+savepath,bbox_inches='tight')
        savepath = savepath[:-4] + '.png'
        plt.savefig(savedir+savepath,bbox_inches='tight')
        # plt.savefig(savedir+savepath,bbox_inches='tight')
    plt.show()

# %%
step_to_token(105837.0)
# Out:
# 239.296610304

# %%
print(rd_clone.keys())
# Out:
# dict_keys(['It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune', 'It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune', 'It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=pile-train Postfix=scratch', 'It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=pile-train Postfix=resume', 'It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune', 'It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch', 'It=132366 WU=0.01 MaxLR=6e-04 MinLR=6e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune'])

# %%
plot_single(filter_=['Tr=pile-train'], #['WU=0.005','WU=0.02','WU=0.0 MaxLR=3e-04','WU=0.0 MaxLR=1.5e-04','WU=0.0 MaxLR=6e-04','27000','10000'],
            upper_limit=300,#step_to_token(105837.0),#300,#step_to_token(105837.0),
            key_to_plot='validation/val_1/lm_loss',#'train/learning_rate',#'validation/val_1/lm_loss',#'train/learning_rate',# #0:pile 1:RP
            ylabel='Tokens (B)',
            xlabel='SlimPajama Val. Loss (downstream)', 
            savepath="model.pdf",
            legend_kwargs=dict(fontsize=9),
            ylim=(2.4,2.9),
            figsize=(9,5),
            warmup_end={'0.01':True,'0.02':False,'0.005':False},
            default_colors=cp1,
            label_dict={x:get_caption(x,use=dict(mx=False,wu=True,mn=True,ds=False,it=False, sh=True)) \
                        for x in rd_clone.keys()})
# Out:
# ['It=132366', 'WU=0.0', 'MaxLR=3e-05', 'MinLR=3e-05', 'Sch=constant', 'Tr=slim-pajama-300B', 'Postfix=finetune']
# ['It=132366', 'WU=0.0', 'MaxLR=3e-05', 'MinLR=3e-05', 'Sch=constant', 'Tr=slim-pajama-300B', 'Postfix=finetune']
# WU
# ['It=132366', 'WU=0.01', 'MaxLR=1.5e-04', 'MinLR=1.5e-05', 'Sch=cosine', 'Tr=slim-pajama-300B', 'Postfix=finetune']
# ['It=132366', 'WU=0.01', 'MaxLR=1.5e-04', 'MinLR=1.5e-05', 'Sch=cosine', 'Tr=slim-pajama-300B', 'Postfix=finetune']
# WU
# ['It=132366', 'WU=0.01', 'MaxLR=3e-04', 'MinLR=3e-05', 'Sch=cosine', 'Tr=pile-train', 'Postfix=scratch']
# ['It=132366', 'WU=0.01', 'MaxLR=3e-04', 'MinLR=3e-05', 'Sch=cosine', 'Tr=pile-train', 'Postfix=scratch']
# WU
# ['It=132366', 'WU=0.01', 'MaxLR=3e-04', 'MinLR=3e-05', 'Sch=cosine', 'Tr=pile-train', 'Postfix=resume']
# ['It=132366', 'WU=0.01', 'MaxLR=3e-04', 'MinLR=3e-05', 'Sch=cosine', 'Tr=pile-train', 'Postfix=resume']
# WU
# ['It=132366', 'WU=0.01', 'MaxLR=3e-04', 'MinLR=3e-05', 'Sch=cosine', 'Tr=slim-pajama-300B', 'Postfix=finetune']
# ['It=132366', 'WU=0.01', 'MaxLR=3e-04', 'MinLR=3e-05', 'Sch=cosine', 'Tr=slim-pajama-300B', 'Postfix=finetune']
# WU
# ['It=132366', 'WU=0.01', 'MaxLR=3e-04', 'MinLR=3e-05', 'Sch=cosine', 'Tr=slim-pajama-300B', 'Postfix=scratch']
# ['It=132366', 'WU=0.01', 'MaxLR=3e-04', 'MinLR=3e-05', 'Sch=cosine', 'Tr=slim-pajama-300B', 'Postfix=scratch']
# WU
# ['It=132366', 'WU=0.01', 'MaxLR=6e-04', 'MinLR=6e-05', 'Sch=cosine', 'Tr=slim-pajama-300B', 'Postfix=finetune']
# ['It=132366', 'WU=0.01', 'MaxLR=6e-04', 'MinLR=6e-05', 'Sch=cosine', 'Tr=slim-pajama-300B', 'Postfix=finetune']
# WU
# 0 It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B Postfix=finetune
# 1 It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 2 It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=pile-train Postfix=scratch
# 3 It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=pile-train Postfix=resume
# 4 It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune
# 5 It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B Postfix=scratch
# 6 It=132366 WU=0.01 MaxLR=6e-04 MinLR=6e-05 Sch=cosine Tr=slim-pajama-300B Postfix=finetune

# %%
plot_single(filter_=['Pile','WU=0.005','WU=0.02',
                        'WU=0.0 MaxLR=3e-04','WU=0.0 MaxLR=1.5e-04',
                        'WU=0.0 MaxLR=6e-04',
                    '27000','10000'],
            upper_limit=step_to_token(105837.0), #300,#step_to_token(105837.0),#300,#step_to_token(105837.0),
            key_to_plot='validation/val_1/lm_loss',#'train/learning_rate',# #0:pile 1:RP
            ylabel='Tokens (B)',
            xlabel='SlimPajama Val. Loss (downstream)', 
            savepath="wu=0.01-RP-val-loss-RP-models-240B.pdf",
            legend_kwargs=dict(fontsize=12),
            ylim=(2.44,2.92),
            figsize=(9,5),
            warmup_end={'0.01':True,'0.02':False,'0.005':False},
           default_colors=cp1,
            label_dict={x:get_caption(x,use=dict(mx=True,wu=False,mn=False,ds=False,it=True)) \
                        for x in rd_clone.keys()})


plot_single(filter_=['Pile','WU=0.005','WU=0.02',
                        'WU=0.0 MaxLR=3e-04','WU=0.0 MaxLR=1.5e-04',
                        'WU=0.0 MaxLR=6e-04',
                    '27000','10000'],
            upper_limit=step_to_token(105837.0),#300,#step_to_token(105837.0),#300,
            key_to_plot='validation/val_0/lm_loss', #0:pile 1:RP
            ylabel='Tokens (B)',
            xlabel='Pile Val. Loss (upstream)', 
            savepath="wu=0.01-Pile-val-loss-RP-models-240B.pdf",
            legend_kwargs=dict(fontsize=12),
            ylim=(2.28,2.92),
            figsize=(9,5),
            warmup_end={'0.01':True,'0.02':False,'0.005':False},
           default_colors=cp1,
            label_dict={x:get_caption(x,use=dict(mx=True,wu=False,mn=False,ds=False,it=True)) \
                        for x in rd_clone.keys()})
# Out:
# ['It=132366', 'WU=0.0', 'MaxLR=3e-05', 'MinLR=3e-05', 'Sch=constant', 'Tr=slim-pajama-300B', 'Postfix=finetune']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [74], in <cell line: 1>()
#       1 plot_single(filter_=['Pile','WU=0.005','WU=0.02',
#       2                         'WU=0.0 MaxLR=3e-04','WU=0.0 MaxLR=1.5e-04',
#       3                         'WU=0.0 MaxLR=6e-04',
#       4                     '27000','10000'],
#       5             upper_limit=step_to_token(105837.0), #300,#step_to_token(105837.0),#300,#step_to_token(105837.0),
#       6             key_to_plot='validation/val_1/lm_loss',#'train/learning_rate',# #0:pile 1:RP
#       7             ylabel='Tokens (B)',
#       8             xlabel='SlimPajama Val. Loss (downstream)',
#       9             savepath="wu=0.01-RP-val-loss-RP-models-240B.pdf",
#      10             legend_kwargs=dict(fontsize=12),
#      11             ylim=(2.44,2.92),
#      12             figsize=(9,5),
#      13             warmup_end={'0.01':True,'0.02':False,'0.005':False},
#      14            default_colors=cp1,
# ---> 15             label_dict={x:get_caption(x,use=dict(mx=True,wu=False,mn=False,ds=False,it=True)) \
#      16                         for x in rd_clone.keys()})
#      19 plot_single(filter_=['Pile','WU=0.005','WU=0.02',
#      20                         'WU=0.0 MaxLR=3e-04','WU=0.0 MaxLR=1.5e-04',
#      21                         'WU=0.0 MaxLR=6e-04',
#    (...)
#      33             label_dict={x:get_caption(x,use=dict(mx=True,wu=False,mn=False,ds=False,it=True)) \
#      34                         for x in rd_clone.keys()})
#
# Input In [74], in <dictcomp>(.0)
#       1 plot_single(filter_=['Pile','WU=0.005','WU=0.02',
#       2                         'WU=0.0 MaxLR=3e-04','WU=0.0 MaxLR=1.5e-04',
#       3                         'WU=0.0 MaxLR=6e-04',
#       4                     '27000','10000'],
#       5             upper_limit=step_to_token(105837.0), #300,#step_to_token(105837.0),#300,#step_to_token(105837.0),
#       6             key_to_plot='validation/val_1/lm_loss',#'train/learning_rate',# #0:pile 1:RP
#       7             ylabel='Tokens (B)',
#       8             xlabel='SlimPajama Val. Loss (downstream)',
#       9             savepath="wu=0.01-RP-val-loss-RP-models-240B.pdf",
#      10             legend_kwargs=dict(fontsize=12),
#      11             ylim=(2.44,2.92),
#      12             figsize=(9,5),
#      13             warmup_end={'0.01':True,'0.02':False,'0.005':False},
#      14            default_colors=cp1,
# ---> 15             label_dict={x:get_caption(x,use=dict(mx=True,wu=False,mn=False,ds=False,it=True)) \
#      16                         for x in rd_clone.keys()})
#      19 plot_single(filter_=['Pile','WU=0.005','WU=0.02',
#      20                         'WU=0.0 MaxLR=3e-04','WU=0.0 MaxLR=1.5e-04',
#      21                         'WU=0.0 MaxLR=6e-04',
#    (...)
#      33             label_dict={x:get_caption(x,use=dict(mx=True,wu=False,mn=False,ds=False,it=True)) \
#      34                         for x in rd_clone.keys()})
#
# Input In [65], in get_caption(key, use)
#       4 print(temp)
#       6 #FIXME: FIX THIS
# ----> 7 if use["sh"]:
#       8     out += f"{'Cosine ' if 'cosine' in key else 'Constant '}"
#      10 if key in ['WU=0.0 MaxLR=3e-05 MinLR=3e-05 RP','WU=0.0 MaxLR=3e-05 MinLR=3e-05 Pile']:
#
# KeyError: 'sh'

# %% [markdown]
# # Main body

# %%
print("overleaf figure 1")
key_to_plot = 'validation/val_0/lm_loss' #pile
key_to_plot = 'validation/val_1/lm_loss' #RP


plot_single(filter_=['Pile','MaxLR=1.5e-04','MaxLR=6e-04','MaxLR=3e-05','WU=0.0005',
                    '27000','10000','scratch'],
            upper_limit=50,
            key_to_plot='validation/val_1/lm_loss', #0:pile 1:RP
            ylabel='Tokens (B)',
            xlabel='SlimPajama Val. Loss (downstream)',
            savepath="lr=3e-4-RP-val-loss-RP-models-50B.pdf",
            legend_kwargs=dict(fontsize=12),
            ylim=(2.66,2.88),#(2.18,2.58),
            figsize=(9,5),
            warmup_end={'0.01':True,'0.02':True,'0.005':True},
           default_colors=cp1,
            label_dict={x:get_caption(x,use=dict(mx=False,wu=True,mn=False,ds=False,it=False)) \
                        for x in rd_clone.keys()})


plot_single(filter_=['Pile','MaxLR=1.5e-04','MaxLR=6e-04','MaxLR=3e-05',
                    '27000','10000','scratch'],
            upper_limit=50,
            key_to_plot='validation/val_0/lm_loss', #0:pile 1:RP
            ylabel='Tokens (B)',
            xlabel='Pile Val. Loss (upstream)',
            savepath="lr=3e-4-pile-val-loss-RP-models-50B.pdf",
            legend_kwargs=dict(fontsize=12),
            ylim=(2.18,2.65),
            figsize=(9,5),
            warmup_end={'0.01':True,'0.02':True,'0.005':True},
           default_colors=cp1,
            label_dict={x:get_caption(x,use=dict(mx=False,wu=True,mn=False,ds=False,it=False)) \
                        for x in rd_clone.keys()})

# %%
plot_single(filter_=['Pile','WU=0.005','WU=0.02',
                        'WU=0.0 MaxLR=3e-04','WU=0.0 MaxLR=1.5e-04',
                        'WU=0.0 MaxLR=6e-04',
                    '27000','10000','scratch'],
            upper_limit=50,
            key_to_plot='validation/val_1/lm_loss', #0:pile 1:RP
            ylabel='Tokens (B)',
            xlabel='SlimPajama Val. Loss (downstream)', 
            savepath="wu=0.01-RP-val-loss-RP-models-50B.pdf",
            legend_kwargs=dict(fontsize=12),
            ylim=(2.61,2.92),
            figsize=(9,5),
            warmup_end={'0.01':True,'0.02':False,'0.005':False},
           default_colors=cp1,
            label_dict={x:get_caption(x,use=dict(mx=True,wu=False,mn=False,ds=False,it=False)) \
                        for x in rd_clone.keys()})

# %%
plot_single(filter_=['WU=0.005','WU=0.02','RP',
                     'WU=0.0 MaxLR=3e-04',
                     'WU=0.0 MaxLR=1.5e-04',
                     'WU=0.0 MaxLR=6e-04'],
            upper_limit=50,
            key_to_plot='validation/val_1/lm_loss', #0:pile 1:RP
            ylabel='Tokens (B)',
            xlabel='SlimPajama Val. Loss (downstream)',
            savepath="wu=0.01-RP-val-loss-Pile-models-50B.pdf",
            legend_kwargs=dict(fontsize=12),
            ylim=(2.72,3.02),
            figsize=(9,5),
            warmup_end={'0.01':True,'0.02':False,'0.005':False},
           default_colors=cp1,
            label_dict={x:get_caption(x,use=dict(mx=True,wu=False,mn=False,ds=False,it=False)) \
                        for x in rd_clone.keys()})


plot_single(filter_=['WU=0.005','WU=0.02','RP',
                     'WU=0.0 MaxLR=3e-04',
                     'WU=0.0 MaxLR=1.5e-04',
                     'WU=0.0 MaxLR=6e-04'],
            upper_limit=50,
            key_to_plot='validation/val_0/lm_loss', #0:pile 1:RP
            ylabel='Tokens (B)',
            xlabel='Pile Val. Loss \n(downstream & upstream)',
            savepath="wu=0.01-Pile-val-loss-Pile-models-50B.pdf",
            legend_kwargs=dict(fontsize=12),
            ylim=(),#(2.72,3.02),
            figsize=(9,5),
            warmup_end={'0.01':True,'0.02':False,'0.005':False},
           default_colors=cp1,
            label_dict={x:get_caption(x,use=dict(mx=True,wu=False,mn=False,ds=False,it=False)) \
                        for x in rd_clone.keys()})

# %%
print("overleaf figure 3")
key_to_plot = 'validation/val_0/lm_loss' #pile
key_to_plot = 'validation/val_1/lm_loss' #RP




cd={
"WU=0.0 MaxLR=3e-04 MinLR=3e-05 RP":'red',
"WU=0.0 MaxLR=3e-04 MinLR=3e-05 RP27000":'blue',
"WU=0.0 MaxLR=3e-04 MinLR=3e-05 RP10000":'black',
"WU=0.01 MaxLR=3e-04 MinLR=3e-05 RP":'red',
"WU=0.01 MaxLR=3e-04 MinLR=3e-05 RP10000":'black',
"WU=0.01 MaxLR=3e-04 MinLR=3e-05 RP27000":'blue',}

cd={
"WU=0.0 MaxLR=3e-04 MinLR=3e-05 RP":cp1[0],
"WU=0.0 MaxLR=3e-04 MinLR=3e-05 RP27000":cp1[2],
"WU=0.0 MaxLR=3e-04 MinLR=3e-05 RP10000":cp1[1],
"WU=0.01 MaxLR=3e-04 MinLR=3e-05 RP":cp1[0],
"WU=0.01 MaxLR=3e-04 MinLR=3e-05 RP10000":cp1[1],
"WU=0.01 MaxLR=3e-04 MinLR=3e-05 RP27000":cp1[2],}

lsd={
"WU=0.0 MaxLR=3e-04 MinLR=3e-05 RP":"--",
"WU=0.0 MaxLR=3e-04 MinLR=3e-05 RP27000":"--",
"WU=0.0 MaxLR=3e-04 MinLR=3e-05 RP10000":"--",
"WU=0.01 MaxLR=3e-04 MinLR=3e-05 RP":"-",
"WU=0.01 MaxLR=3e-04 MinLR=3e-05 RP10000":"-",
"WU=0.01 MaxLR=3e-04 MinLR=3e-05 RP27000":"-",}


plot_single(filter_=['Pile','MaxLR=1.5e-04','MaxLR=6e-04','MaxLR=3e-05','WU=0.005','WU=0.02',
                'scratch'],
            upper_limit=50,
            key_to_plot='validation/val_1/lm_loss', #0:pile 1:RP
            ylabel='Tokens (B)',
            xlabel='SlimPajama Val. Loss (downstream)',
            savepath="lr=3e-4-RP-val-loss-RP-10-27-models-50B.pdf",
            legend_kwargs=dict(fontsize=12),
            ylim=(2.62,3.15),#(2.18,2.58),
            figsize=(9,5),
            warmup_end={'0.01':True,'0.02':False,'0.005':False},
           color_dict=cd,
           ls_dict=lsd,
            label_dict={x:get_caption(x,use=dict(mx=False,wu=True,mn=False,ds=False,it=True)) \
                        for x in rd_clone.keys()})


plot_single(filter_=['Pile','MaxLR=1.5e-04','MaxLR=6e-04','MaxLR=3e-05','WU=0.005','WU=0.02',
                   'scratch'],
            upper_limit=50,
            key_to_plot='validation/val_0/lm_loss', #0:pile 1:RP
            ylabel='Tokens (B)',
            xlabel='Pile Val. Loss (upstream)',
            savepath="lr=3e-4-pile-val-loss-RP-10-27-models-50B.pdf",
            legend_kwargs=dict(fontsize=12),
            ylim=(2.18,2.78),
            figsize=(9,5),
            warmup_end={'0.01':True,'0.02':False,'0.005':False},
           color_dict=cd,
           ls_dict=lsd,
            label_dict={x:get_caption(x,use=dict(mx=True,wu=False,mn=False,ds=False,it=True)) \
                        for x in rd_clone.keys()})

# %% [markdown]
# # Appendix figues

# %%
ls1 = ['-', '--', '-.', ':']
plot_single(filter_=['Pile',#'MaxLR=1.5e-04',#'MaxLR=6e-04','MaxLR=3e-05',
                    '27000','10000','scratch'],
            upper_limit=50,
            key_to_plot='validation/val_0/lm_loss', #0:pile 1:RP
            ylabel='Tokens (B)',
            xlabel='Pile Val. Loss (upstream)',
            savepath="all-pile-val-loss-RP-models-50B.pdf",
            legend_kwargs=dict(fontsize=7),
            ylim=(2.18, 2.65),
            figsize=(7.5,5),
            warmup_end={'0.01':True,'0.02':True,'0.005':True},
           circles=True,
            default_ls =["-"] +[ls1[y] for x in range(3)for y in range(4)],
           default_colors=[cp1[3]] +[cp1[x] for x in range(3)for y in range(4)],
            label_dict={x:get_caption(x,use=dict(mx=True,wu=True,mn=False,ds=False,it=False)) \
                        for x in rd_clone.keys()})

# %%
[cp1[0]] +[cp1[x] for x in range(4)for y in range(3)]

# %%
ls1 = ['-', '--', '-.', ':']

plot_single(filter_=['Pile',
                    '27000','10000','scratch'],
            upper_limit=50,
            key_to_plot='validation/val_1/lm_loss', #0:pile 1:RP
            ylabel='Tokens (B)',
            xlabel='Red Pajama Val. Loss (downstream)',
            savepath="all-RP-val-loss-RP-models-50B.pdf",
            legend_kwargs=dict(fontsize=6),
            ylim=(2.61,2.88),#(2.18,2.58),
            figsize=(7.5,5),
            warmup_end={'0.01':True,'0.02':True,'0.005':True},
            default_ls =['-'] +[ls1[y] for x in range(3)for y in range(4)],
           default_colors=[cp1[3]] +[cp1[x] for x in range(3)for y in range(4)])

# %%
print("overleaf figure 3")
key_to_plot = 'validation/val_0/lm_loss' #pile
key_to_plot = 'validation/val_1/lm_loss' #RP




cd={
"WU=0.0 MaxLR=3e-04 MinLR=3e-05 RP":'red',
"WU=0.0 MaxLR=3e-04 MinLR=3e-05 RP27000":'blue',
"WU=0.0 MaxLR=3e-04 MinLR=3e-05 RP10000":'black',
"WU=0.01 MaxLR=3e-04 MinLR=3e-05 RP":'red',
"WU=0.01 MaxLR=3e-04 MinLR=3e-05 RP10000":'black',
"WU=0.01 MaxLR=3e-04 MinLR=3e-05 RP27000":'blue',}

cd={
"WU=0.0 MaxLR=3e-04 MinLR=3e-05 RP":cp1[0],
"WU=0.0 MaxLR=3e-04 MinLR=3e-05 RP27000":cp1[2],
"WU=0.0 MaxLR=3e-04 MinLR=3e-05 RP10000":cp1[1],
"WU=0.01 MaxLR=3e-04 MinLR=3e-05 RP":cp1[0],
"WU=0.01 MaxLR=3e-04 MinLR=3e-05 RPscratch":cp1[3],
"WU=0.01 MaxLR=3e-04 MinLR=3e-05 RP10000":cp1[1],
"WU=0.01 MaxLR=3e-04 MinLR=3e-05 RP27000":cp1[2],}

lsd={
"WU=0.0 MaxLR=3e-04 MinLR=3e-05 RP":"--",
"WU=0.0 MaxLR=3e-04 MinLR=3e-05 RP27000":"--",
"WU=0.0 MaxLR=3e-04 MinLR=3e-05 RP10000":"--",
"WU=0.01 MaxLR=3e-04 MinLR=3e-05 RP":"-",
"WU=0.01 MaxLR=3e-04 MinLR=3e-05 RP10000":"-",
"WU=0.01 MaxLR=3e-04 MinLR=3e-05 RP27000":"-",}


plot_single(filter_=['Pile','MaxLR=1.5e-04','MaxLR=6e-04','MaxLR=3e-05','WU=0.005','WU=0.02',
#                 'scratch'
                    ],
            upper_limit=50,
            key_to_plot='validation/val_1/lm_loss', #0:pile 1:RP
            ylabel='Tokens (B)',
            xlabel='SlimPajama Val. Loss (downstream)',
            savepath="lr=3e-4-RP-val-loss-RP-10-27-scratch-models-50B.pdf",
            legend_kwargs=dict(fontsize=12),
            ylim=(2.62,3.15),#(2.18,2.58),
            figsize=(9,5),
            warmup_end={'0.01':True,'0.02':False,'0.005':False},
           color_dict=cd,
           ls_dict=lsd,
            label_dict={x:get_caption(x,use=dict(mx=False,wu=True,mn=False,ds=False,it=True)) \
                        for x in rd_clone.keys()})


plot_single(filter_=['Pile','MaxLR=1.5e-04','MaxLR=6e-04','MaxLR=3e-05','WU=0.005','WU=0.02',
#                    'scratch'
                    ],
            upper_limit=50,
            key_to_plot='validation/val_0/lm_loss', #0:pile 1:RP
            ylabel='Tokens (B)',
            xlabel='Pile Val. Loss (upstream)',
            savepath="lr=3e-4-pile-val-loss-RP-10-27-scratch-models-50B.pdf",
            legend_kwargs=dict(fontsize=12),
            ylim=(2.18,2.83),
            figsize=(9,5),
            warmup_end={'0.01':True,'0.02':False,'0.005':False},
           color_dict=cd,
           ls_dict=lsd,
            label_dict={x:get_caption(x,use=dict(mx=False,wu=True,mn=False,ds=False,it=True)) \
                        for x in rd_clone.keys()})
# Out:
# overleaf figure 3
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [38], in <cell line: 34>()
#      16 cd={
#      17 "WU=0.0 MaxLR=3e-04 MinLR=3e-05 RP":cp1[0],
#      18 "WU=0.0 MaxLR=3e-04 MinLR=3e-05 RP27000":cp1[2],
#    (...)
#      22 "WU=0.01 MaxLR=3e-04 MinLR=3e-05 RP10000":cp1[1],
#      23 "WU=0.01 MaxLR=3e-04 MinLR=3e-05 RP27000":cp1[2],}
#      25 lsd={
#      26 "WU=0.0 MaxLR=3e-04 MinLR=3e-05 RP":"--",
#      27 "WU=0.0 MaxLR=3e-04 MinLR=3e-05 RP27000":"--",
#    (...)
#      30 "WU=0.01 MaxLR=3e-04 MinLR=3e-05 RP10000":"-",
#      31 "WU=0.01 MaxLR=3e-04 MinLR=3e-05 RP27000":"-",}
# ---> 34 plot_single(filter_=['Pile','MaxLR=1.5e-04','MaxLR=6e-04','MaxLR=3e-05','WU=0.005','WU=0.02',
#      35 #                 'scratch'
#      36                     ],
#      37             upper_limit=50,
#      38             key_to_plot='validation/val_1/lm_loss', #0:pile 1:RP
#      39             ylabel='Tokens (B)',
#      40             xlabel='SlimPajama Val. Loss (downstream)',
#      41             savepath="lr=3e-4-RP-val-loss-RP-10-27-scratch-models-50B.pdf",
#      42             legend_kwargs=dict(fontsize=12),
#      43             ylim=(2.62,3.15),#(2.18,2.58),
#      44             figsize=(9,5),
#      45             warmup_end={'0.01':True,'0.02':False,'0.005':False},
#      46            color_dict=cd,
#      47            ls_dict=lsd,
#      48             label_dict={x:get_caption(x,use=dict(mx=False,wu=True,mn=False,ds=False,it=True)) \
#      49                         for x in rd_clone.keys()})
#      52 plot_single(filter_=['Pile','MaxLR=1.5e-04','MaxLR=6e-04','MaxLR=3e-05','WU=0.005','WU=0.02',
#      53 #                    'scratch'
#      54                     ],
#    (...)
#      66             label_dict={x:get_caption(x,use=dict(mx=False,wu=True,mn=False,ds=False,it=True)) \
#      67                         for x in rd_clone.keys()})
#
# Input In [34], in plot_single(filter_, upper_limit, key_to_plot, ylabel, xlabel, savepath, legend_kwargs, ylim, figsize, warmup_end, savedir, color_dict, ls_dict, circles, default_colors, default_ls, label_dict)
#      94 ax.set_ylim(*ylim)
#      95 if savepath:
# ---> 96     plt.savefig(savedir+savepath,bbox_inches='tight')
#      97     savepath = savepath[:-4] + '.png'
#      98     plt.savefig(savedir+savepath,bbox_inches='tight')
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:958, in savefig(*args, **kwargs)
#     955 @_copy_docstring_and_deprecators(Figure.savefig)
#     956 def savefig(*args, **kwargs):
#     957     fig = gcf()
# --> 958     res = fig.savefig(*args, **kwargs)
#     959     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     960     return res
#
# File ~\anaconda3\lib\site-packages\matplotlib\figure.py:3019, in Figure.savefig(self, fname, transparent, **kwargs)
#    3015     for ax in self.axes:
#    3016         stack.enter_context(
#    3017             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3019 self.canvas.print_figure(fname, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py:2319, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2315 try:
#    2316     # _get_renderer may change the figure dpi (as vector formats
#    2317     # force the figure dpi to 72), so we need to set it again here.
#    2318     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319         result = print_method(
#    2320             filename,
#    2321             facecolor=facecolor,
#    2322             edgecolor=edgecolor,
#    2323             orientation=orientation,
#    2324             bbox_inches_restore=_bbox_inches_restore,
#    2325             **kwargs)
#    2326 finally:
#    2327     if bbox_inches and restore_bbox:
#
# File ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py:1648, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1640     _api.warn_deprecated(
#    1641         '3.3', name=name, removal='3.6',
#    1642         message='%(name)s() got unexpected keyword argument "'
#    1643                 + arg + '" which is no longer supported as of '
#    1644                 '%(since)s and will become an error '
#    1645                 '%(removal)s')
#    1646     kwargs.pop(arg)
# -> 1648 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py:386, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     381 @functools.wraps(func)
#     382 def wrapper(*inner_args, **inner_kwargs):
#     383     if len(inner_args) <= name_idx and name not in inner_kwargs:
#     384         # Early return in the simple, non-deprecated case (much faster than
#     385         # calling bind()).
# --> 386         return func(*inner_args, **inner_kwargs)
#     387     arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     388     if is_varargs and arguments.get(name):
#
# File ~\anaconda3\lib\site-packages\matplotlib\backends\backend_pdf.py:2778, in FigureCanvasPdf.print_pdf(self, filename, dpi, bbox_inches_restore, metadata)
#    2776     file = filename._file
#    2777 else:
# -> 2778     file = PdfFile(filename, metadata=metadata)
#    2779 try:
#    2780     file.newPage(width, height)
#
# File ~\anaconda3\lib\site-packages\matplotlib\backends\backend_pdf.py:654, in PdfFile.__init__(self, filename, metadata)
#     652 self.original_file_like = None
#     653 self.tell_base = 0
# --> 654 fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#     655 if not opened:
#     656     try:
#
# File ~\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:451, in to_filehandle(fname, flag, return_opened, encoding)
#     449         fh = bz2.BZ2File(fname, flag)
#     450     else:
# --> 451         fh = open(fname, flag, encoding=encoding)
#     452     opened = True
#     453 elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'esfomows/lr=3e-4-RP-val-loss-RP-10-27-scratch-models-50B.pdf'

# %%
import random
random.seed(5)
marker_styles = ['.', ',', 'o', 'v', '^', '<', '>', '1', '2', '3', '4', 's', 'p', '*', 'h', '+', 'x', 'D', 'd', '_', '|']
random.shuffle(marker_styles)

# %%
import numpy as np
step_to_token = lambda x : x * 2260992/1000000000

def plot_with_cmap(filter_=['Pile','MaxLR=1.5e-04','MaxLR=6e-04','MaxLR=3e-05'],
                upper_limit=50,
                key_to_plot='validation/val_0/lm_loss',
                ylabel='Tokens (B)',
                xlabel='Pile Val Loss',
                savepath=None, #"lr3e-4-Pile-val-loss-warmup-50B.pdf",
                legend_kwargs=dict(fontsize=12),
                ylim=(2.18,2.55),
                figsize=(7.5,5),
                warmup_end={'0.01':True,'0.02':True,'0.005':True},
                skip=6,
                cmap_label='Tokens (B)',
                key_map={},
                savedir='esfomows/',
               ):

    fig, ax = plt.subplots(figsize=figsize)
    cmap = plt.cm.viridis

    for i,(k,v) in enumerate(rd_clone.items()):
        if len(v) == 0 or reduce(np.logical_or,[x in k for x in filter_]):
            continue
            
        print(f"\"{k}\":")
            
        v0 = np.array(v['validation/val_0/lm_loss_ppl']) #pile
        v1 = np.array(v['validation/val_1/lm_loss_ppl']) #red pajama
        
        if v1.shape != v0.shape:
            v0 = v0[:v1.shape[0],:]
        iters_ = step_to_token(v0[:,0])
        
        w = np.where(iters_ < upper_limit)
        v0 = v0[w[0],:]
        v1 = v1[w[0],:]

        scatter = ax.scatter(
                   v1[::skip,1],
                   v0[::skip,1],
                   c=step_to_token(v0[::skip,0]),
                   label=key_map.get(k,k),
                   marker=marker_styles[i],
                   cmap=cmap)
        scatter.set_clim(0,upper_limit)

        ax.set_ylabel(ylabel)
        ax.set_xlabel(xlabel)

    for i,(k,v) in enumerate(rd_clone.items()):  
        if len(v) == 0 or reduce(np.logical_or,[x in k for x in filter_]):
            continue

        v0 = np.array(v['validation/val_0/lm_loss_ppl']) #pile
        v1 = np.array(v['validation/val_1/lm_loss_ppl']) #red pajama
        # 662, 1318, 2633
        ax.scatter(v1[0,1],
                   v0[0,1],
                   color='red',
                   marker=marker_styles[i])
            
        if warmup_end['0.005']:
            w = np.where(np.logical_and(v0[:,0]<670,650<v0[:,0]))
            print(w)
            ax.scatter(v1[w,1],
                       v0[w,1],
                       color='lime',
                       marker=marker_styles[i])
            
        if warmup_end['0.01']:
            w = np.where(np.logical_and(v0[:,0]<1330,1310<v0[:,0]))
            ax.scatter(v1[w,1],
                       v0[w,1],
                       color='lime',
                       marker=marker_styles[i])
        
        if warmup_end['0.02']:
            w = np.where(np.logical_and(v0[:,0]<2640,2620<v0[:,0]))
            ax.scatter(v1[w,1],
                       v0[w,1],
                       color='lime',
                       marker=marker_styles[i])

        

    ax.legend(**legend_kwargs)


    sm = plt.colorbar(scatter, #plt.cm.ScalarMappable(), 
                      ax=ax, 
                      cmap=cmap)#, clim=(0,100))
    # Customize colorbar
    sm.set_label(cmap_label)
    if savepath:
        plt.savefig(savedir+savepath,bbox_inches='tight')
        savepath = savepath[:-4] + '.png'
        plt.savefig(savedir+savepath,bbox_inches='tight')
    plt.show()

# %%
plot_with_cmap(filter_=['WU=0.005','WU=0.02','Pile',
                        'WU=0.0 MaxLR=3e-04','WU=0.0 MaxLR=1.5e-04',
                        'WU=0.0 MaxLR=6e-04',
                        '27000','10000','scratch'
                       ],
                upper_limit=50,
                key_to_plot='validation/val_0/lm_loss',
                ylabel='Pile Val PPL (upstream)',
                xlabel='SlimPajama Val PPL (downstream)',
                savepath="wu=0.01-pile-RP-val-loss-RP-models-50B.pdf",
                legend_kwargs=dict(fontsize=11,loc="lower right"),
                ylim=(2.18,2.55),
                figsize=(7.5,5),
                warmup_end={'0.01':True,'0.02':True,'0.005':True},
                skip=6,
                cmap_label='Tokens (B)',
            key_map={x:get_caption(x,use=dict(mx=True,wu=False,mn=False,ds=False,it=False)) \
                        for x in rd_clone.keys()}
#                key_map={
#                    "WU=0.0 MaxLR=3e-05 MinLR=3e-05 RP": "3e-05 Constant WU=0.0",
#                    "WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 RP": "1.5e-04 consine WU=0.01",
#                     "WU=0.01 MaxLR=3e-04 MinLR=3e-05 RP": "3e-04 consine WU=0.01",
#                     "WU=0.01 MaxLR=6e-04 MinLR=6e-05 RP": "6e-04 cosine WU=0.01",
                   
#                }
               )
# Out:
# "It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B finetune":
# "It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B finetune":
# "It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=pile-train resume":
# "It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B finetune":
# "It=132366 WU=0.01 MaxLR=6e-04 MinLR=6e-05 Sch=cosine Tr=slim-pajama-300B finetune":
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 plot_with_cmap(filter_=['WU=0.005','WU=0.02','Pile',
#       2                         'WU=0.0 MaxLR=3e-04','WU=0.0 MaxLR=1.5e-04',
#       3                         'WU=0.0 MaxLR=6e-04',
#       4                         '27000','10000','scratch'
#       5                        ],
#       6                 upper_limit=50,
#       7                 key_to_plot='validation/val_0/lm_loss',
#       8                 ylabel='Pile Val PPL (upstream)',
#       9                 xlabel='SlimPajama Val PPL (downstream)',
#      10                 savepath="wu=0.01-pile-RP-val-loss-RP-models-50B.pdf",
#      11                 legend_kwargs=dict(fontsize=11,loc="lower right"),
#      12                 ylim=(2.18,2.55),
#      13                 figsize=(7.5,5),
#      14                 warmup_end={'0.01':True,'0.02':True,'0.005':True},
#      15                 skip=6,
#      16                 cmap_label='Tokens (B)',
#      17             key_map={x:get_caption(x,use=dict(mx=True,wu=False,mn=False,ds=False,it=False)) \
#      18                         for x in rd_clone.keys()}
#      19 #                key_map={
#      20 #                    "WU=0.0 MaxLR=3e-05 MinLR=3e-05 RP": "3e-05 Constant WU=0.0",
#      21 #                    "WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 RP": "1.5e-04 consine WU=0.01",
#      22 #                     "WU=0.01 MaxLR=3e-04 MinLR=3e-05 RP": "3e-04 consine WU=0.01",
#      23 #                     "WU=0.01 MaxLR=6e-04 MinLR=6e-05 RP": "6e-04 cosine WU=0.01",
#      24
#      25 #                }
#      26                )
#
# Input In [40], in plot_with_cmap(filter_, upper_limit, key_to_plot, ylabel, xlabel, savepath, legend_kwargs, ylim, figsize, warmup_end, skip, cmap_label, key_map, savedir)
#      95 sm.set_label(cmap_label)
#      96 if savepath:
# ---> 97     plt.savefig(savedir+savepath,bbox_inches='tight')
#      98     savepath = savepath[:-4] + '.png'
#      99     plt.savefig(savedir+savepath,bbox_inches='tight')
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:958, in savefig(*args, **kwargs)
#     955 @_copy_docstring_and_deprecators(Figure.savefig)
#     956 def savefig(*args, **kwargs):
#     957     fig = gcf()
# --> 958     res = fig.savefig(*args, **kwargs)
#     959     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     960     return res
#
# File ~\anaconda3\lib\site-packages\matplotlib\figure.py:3019, in Figure.savefig(self, fname, transparent, **kwargs)
#    3015     for ax in self.axes:
#    3016         stack.enter_context(
#    3017             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3019 self.canvas.print_figure(fname, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py:2319, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2315 try:
#    2316     # _get_renderer may change the figure dpi (as vector formats
#    2317     # force the figure dpi to 72), so we need to set it again here.
#    2318     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319         result = print_method(
#    2320             filename,
#    2321             facecolor=facecolor,
#    2322             edgecolor=edgecolor,
#    2323             orientation=orientation,
#    2324             bbox_inches_restore=_bbox_inches_restore,
#    2325             **kwargs)
#    2326 finally:
#    2327     if bbox_inches and restore_bbox:
#
# File ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py:1648, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1640     _api.warn_deprecated(
#    1641         '3.3', name=name, removal='3.6',
#    1642         message='%(name)s() got unexpected keyword argument "'
#    1643                 + arg + '" which is no longer supported as of '
#    1644                 '%(since)s and will become an error '
#    1645                 '%(removal)s')
#    1646     kwargs.pop(arg)
# -> 1648 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py:386, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     381 @functools.wraps(func)
#     382 def wrapper(*inner_args, **inner_kwargs):
#     383     if len(inner_args) <= name_idx and name not in inner_kwargs:
#     384         # Early return in the simple, non-deprecated case (much faster than
#     385         # calling bind()).
# --> 386         return func(*inner_args, **inner_kwargs)
#     387     arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     388     if is_varargs and arguments.get(name):
#
# File ~\anaconda3\lib\site-packages\matplotlib\backends\backend_pdf.py:2778, in FigureCanvasPdf.print_pdf(self, filename, dpi, bbox_inches_restore, metadata)
#    2776     file = filename._file
#    2777 else:
# -> 2778     file = PdfFile(filename, metadata=metadata)
#    2779 try:
#    2780     file.newPage(width, height)
#
# File ~\anaconda3\lib\site-packages\matplotlib\backends\backend_pdf.py:654, in PdfFile.__init__(self, filename, metadata)
#     652 self.original_file_like = None
#     653 self.tell_base = 0
# --> 654 fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#     655 if not opened:
#     656     try:
#
# File ~\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:451, in to_filehandle(fname, flag, return_opened, encoding)
#     449         fh = bz2.BZ2File(fname, flag)
#     450     else:
# --> 451         fh = open(fname, flag, encoding=encoding)
#     452     opened = True
#     453 elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'esfomows/wu=0.01-pile-RP-val-loss-RP-models-50B.pdf'

# %%
# random.seed(3)
# marker_styles = ['.', ',', 'o', 'v', '^', '<', '>', '1', '2', '3', '4', 's', 'p', '*', 'h', '+', 'x', 'D', 'd', '_', '|']
# random.shuffle(marker_styles)

# %%
plot_with_cmap(filter_=['WU=0.005','WU=0.02','RP',
                        'WU=0.0 MaxLR=3e-04','WU=0.0 MaxLR=1.5e-04',
                        'WU=0.0 MaxLR=6e-04',
                        '27000','10000'],
                upper_limit=50,
                key_to_plot='validation/val_0/lm_loss',
                ylabel='Pile Val PPL (upstream)',
                xlabel='SlimPajama Val PPL (downstream)',
                savepath="wu=0.01-pile-RP-val-ppl-pile-models-50B.pdf",
                legend_kwargs=dict(fontsize=12),
                ylim=(2.18,2.55),
                figsize=(7.5,5),
                warmup_end={'0.01':True,'0.02':False,'0.005':False},
                skip=6,
                cmap_label='Tokens (B)',
            key_map={x:get_caption(x,use=dict(mx=True,wu=False,mn=False,ds=False,it=False)) \
                        for x in rd_clone.keys()}
               )
# Out:
# "It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B scratch":
# "It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B finetune":
# "It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B scratch":
# "It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B finetune":
# "It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=pile-train scratch":
# "It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=pile-train resume":
# "It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B scratch":
# "It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B finetune":
# "It=132366 WU=0.01 MaxLR=6e-04 MinLR=6e-05 Sch=cosine Tr=slim-pajama-300B scratch":
# "It=132366 WU=0.01 MaxLR=6e-04 MinLR=6e-05 Sch=cosine Tr=slim-pajama-300B finetune":
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 plot_with_cmap(filter_=['WU=0.005','WU=0.02','RP',
#       2                         'WU=0.0 MaxLR=3e-04','WU=0.0 MaxLR=1.5e-04',
#       3                         'WU=0.0 MaxLR=6e-04',
#       4                         '27000','10000'],
#       5                 upper_limit=50,
#       6                 key_to_plot='validation/val_0/lm_loss',
#       7                 ylabel='Pile Val PPL (upstream)',
#       8                 xlabel='SlimPajama Val PPL (downstream)',
#       9                 savepath="wu=0.01-pile-RP-val-ppl-pile-models-50B.pdf",
#      10                 legend_kwargs=dict(fontsize=12),
#      11                 ylim=(2.18,2.55),
#      12                 figsize=(7.5,5),
#      13                 warmup_end={'0.01':True,'0.02':False,'0.005':False},
#      14                 skip=6,
#      15                 cmap_label='Tokens (B)',
#      16             key_map={x:get_caption(x,use=dict(mx=True,wu=False,mn=False,ds=False,it=False)) \
#      17                         for x in rd_clone.keys()}
#      18                )
#
# Input In [40], in plot_with_cmap(filter_, upper_limit, key_to_plot, ylabel, xlabel, savepath, legend_kwargs, ylim, figsize, warmup_end, skip, cmap_label, key_map, savedir)
#      95 sm.set_label(cmap_label)
#      96 if savepath:
# ---> 97     plt.savefig(savedir+savepath,bbox_inches='tight')
#      98     savepath = savepath[:-4] + '.png'
#      99     plt.savefig(savedir+savepath,bbox_inches='tight')
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:958, in savefig(*args, **kwargs)
#     955 @_copy_docstring_and_deprecators(Figure.savefig)
#     956 def savefig(*args, **kwargs):
#     957     fig = gcf()
# --> 958     res = fig.savefig(*args, **kwargs)
#     959     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     960     return res
#
# File ~\anaconda3\lib\site-packages\matplotlib\figure.py:3019, in Figure.savefig(self, fname, transparent, **kwargs)
#    3015     for ax in self.axes:
#    3016         stack.enter_context(
#    3017             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3019 self.canvas.print_figure(fname, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py:2319, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2315 try:
#    2316     # _get_renderer may change the figure dpi (as vector formats
#    2317     # force the figure dpi to 72), so we need to set it again here.
#    2318     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319         result = print_method(
#    2320             filename,
#    2321             facecolor=facecolor,
#    2322             edgecolor=edgecolor,
#    2323             orientation=orientation,
#    2324             bbox_inches_restore=_bbox_inches_restore,
#    2325             **kwargs)
#    2326 finally:
#    2327     if bbox_inches and restore_bbox:
#
# File ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py:1648, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1640     _api.warn_deprecated(
#    1641         '3.3', name=name, removal='3.6',
#    1642         message='%(name)s() got unexpected keyword argument "'
#    1643                 + arg + '" which is no longer supported as of '
#    1644                 '%(since)s and will become an error '
#    1645                 '%(removal)s')
#    1646     kwargs.pop(arg)
# -> 1648 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py:386, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     381 @functools.wraps(func)
#     382 def wrapper(*inner_args, **inner_kwargs):
#     383     if len(inner_args) <= name_idx and name not in inner_kwargs:
#     384         # Early return in the simple, non-deprecated case (much faster than
#     385         # calling bind()).
# --> 386         return func(*inner_args, **inner_kwargs)
#     387     arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     388     if is_varargs and arguments.get(name):
#
# File ~\anaconda3\lib\site-packages\matplotlib\backends\backend_pdf.py:2778, in FigureCanvasPdf.print_pdf(self, filename, dpi, bbox_inches_restore, metadata)
#    2776     file = filename._file
#    2777 else:
# -> 2778     file = PdfFile(filename, metadata=metadata)
#    2779 try:
#    2780     file.newPage(width, height)
#
# File ~\anaconda3\lib\site-packages\matplotlib\backends\backend_pdf.py:654, in PdfFile.__init__(self, filename, metadata)
#     652 self.original_file_like = None
#     653 self.tell_base = 0
# --> 654 fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#     655 if not opened:
#     656     try:
#
# File ~\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:451, in to_filehandle(fname, flag, return_opened, encoding)
#     449         fh = bz2.BZ2File(fname, flag)
#     450     else:
# --> 451         fh = open(fname, flag, encoding=encoding)
#     452     opened = True
#     453 elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'esfomows/wu=0.01-pile-RP-val-ppl-pile-models-50B.pdf'

# %%
plot_with_cmap(filter_=['WU=0.005','WU=0.02','Pile',
                        'WU=0.0 MaxLR=3e-04','WU=0.0 MaxLR=1.5e-04',
                        'WU=0.0 MaxLR=6e-04',
                        '27000','10000','scratch'
                       ],
                upper_limit=300,
                key_to_plot='validation/val_0/lm_loss',
                ylabel='Pile Val PPL (upstream)',
                xlabel='SlimPajama Val PPL (downstream)',
                savepath="wu=0.01-pile-RP-val-loss-RP-models-300B.pdf",
                legend_kwargs=dict(fontsize=11,loc="lower right"),
                ylim=(2.18,2.55),
                figsize=(7.5,5),
                warmup_end={'0.01':True,'0.02':True,'0.005':True},
                skip=15,
                cmap_label='Tokens (B)',
            key_map={x:get_caption(x,use=dict(mx=True,wu=False,mn=False,ds=False,it=False)) \
                        for x in rd_clone.keys()}
#                key_map={
#                    "WU=0.0 MaxLR=3e-05 MinLR=3e-05 RP": "3e-05 Constant WU=0.0",
#                    "WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 RP": "1.5e-04 consine WU=0.01",
#                     "WU=0.01 MaxLR=3e-04 MinLR=3e-05 RP": "3e-04 consine WU=0.01",
#                     "WU=0.01 MaxLR=6e-04 MinLR=6e-05 RP": "6e-04 cosine WU=0.01",
                   
#                }
               )# to 300B
# Out:
# "It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B finetune":
# "It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B finetune":
# "It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=pile-train resume":
# "It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B finetune":
# "It=132366 WU=0.01 MaxLR=6e-04 MinLR=6e-05 Sch=cosine Tr=slim-pajama-300B finetune":
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [44], in <cell line: 1>()
# ----> 1 plot_with_cmap(filter_=['WU=0.005','WU=0.02','Pile',
#       2                         'WU=0.0 MaxLR=3e-04','WU=0.0 MaxLR=1.5e-04',
#       3                         'WU=0.0 MaxLR=6e-04',
#       4                         '27000','10000','scratch'
#       5                        ],
#       6                 upper_limit=300,
#       7                 key_to_plot='validation/val_0/lm_loss',
#       8                 ylabel='Pile Val PPL (upstream)',
#       9                 xlabel='SlimPajama Val PPL (downstream)',
#      10                 savepath="wu=0.01-pile-RP-val-loss-RP-models-300B.pdf",
#      11                 legend_kwargs=dict(fontsize=11,loc="lower right"),
#      12                 ylim=(2.18,2.55),
#      13                 figsize=(7.5,5),
#      14                 warmup_end={'0.01':True,'0.02':True,'0.005':True},
#      15                 skip=15,
#      16                 cmap_label='Tokens (B)',
#      17             key_map={x:get_caption(x,use=dict(mx=True,wu=False,mn=False,ds=False,it=False)) \
#      18                         for x in rd_clone.keys()}
#      19 #                key_map={
#      20 #                    "WU=0.0 MaxLR=3e-05 MinLR=3e-05 RP": "3e-05 Constant WU=0.0",
#      21 #                    "WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 RP": "1.5e-04 consine WU=0.01",
#      22 #                     "WU=0.01 MaxLR=3e-04 MinLR=3e-05 RP": "3e-04 consine WU=0.01",
#      23 #                     "WU=0.01 MaxLR=6e-04 MinLR=6e-05 RP": "6e-04 cosine WU=0.01",
#      24
#      25 #                }
#      26                )
#
# Input In [40], in plot_with_cmap(filter_, upper_limit, key_to_plot, ylabel, xlabel, savepath, legend_kwargs, ylim, figsize, warmup_end, skip, cmap_label, key_map, savedir)
#      95 sm.set_label(cmap_label)
#      96 if savepath:
# ---> 97     plt.savefig(savedir+savepath,bbox_inches='tight')
#      98     savepath = savepath[:-4] + '.png'
#      99     plt.savefig(savedir+savepath,bbox_inches='tight')
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:958, in savefig(*args, **kwargs)
#     955 @_copy_docstring_and_deprecators(Figure.savefig)
#     956 def savefig(*args, **kwargs):
#     957     fig = gcf()
# --> 958     res = fig.savefig(*args, **kwargs)
#     959     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     960     return res
#
# File ~\anaconda3\lib\site-packages\matplotlib\figure.py:3019, in Figure.savefig(self, fname, transparent, **kwargs)
#    3015     for ax in self.axes:
#    3016         stack.enter_context(
#    3017             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3019 self.canvas.print_figure(fname, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py:2319, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2315 try:
#    2316     # _get_renderer may change the figure dpi (as vector formats
#    2317     # force the figure dpi to 72), so we need to set it again here.
#    2318     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319         result = print_method(
#    2320             filename,
#    2321             facecolor=facecolor,
#    2322             edgecolor=edgecolor,
#    2323             orientation=orientation,
#    2324             bbox_inches_restore=_bbox_inches_restore,
#    2325             **kwargs)
#    2326 finally:
#    2327     if bbox_inches and restore_bbox:
#
# File ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py:1648, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1640     _api.warn_deprecated(
#    1641         '3.3', name=name, removal='3.6',
#    1642         message='%(name)s() got unexpected keyword argument "'
#    1643                 + arg + '" which is no longer supported as of '
#    1644                 '%(since)s and will become an error '
#    1645                 '%(removal)s')
#    1646     kwargs.pop(arg)
# -> 1648 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py:386, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     381 @functools.wraps(func)
#     382 def wrapper(*inner_args, **inner_kwargs):
#     383     if len(inner_args) <= name_idx and name not in inner_kwargs:
#     384         # Early return in the simple, non-deprecated case (much faster than
#     385         # calling bind()).
# --> 386         return func(*inner_args, **inner_kwargs)
#     387     arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     388     if is_varargs and arguments.get(name):
#
# File ~\anaconda3\lib\site-packages\matplotlib\backends\backend_pdf.py:2778, in FigureCanvasPdf.print_pdf(self, filename, dpi, bbox_inches_restore, metadata)
#    2776     file = filename._file
#    2777 else:
# -> 2778     file = PdfFile(filename, metadata=metadata)
#    2779 try:
#    2780     file.newPage(width, height)
#
# File ~\anaconda3\lib\site-packages\matplotlib\backends\backend_pdf.py:654, in PdfFile.__init__(self, filename, metadata)
#     652 self.original_file_like = None
#     653 self.tell_base = 0
# --> 654 fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#     655 if not opened:
#     656     try:
#
# File ~\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:451, in to_filehandle(fname, flag, return_opened, encoding)
#     449         fh = bz2.BZ2File(fname, flag)
#     450     else:
# --> 451         fh = open(fname, flag, encoding=encoding)
#     452     opened = True
#     453 elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'esfomows/wu=0.01-pile-RP-val-loss-RP-models-300B.pdf'

# %%
plot_with_cmap(filter_=['WU=0.005','WU=0.02','Pile',
                        'WU=0.0 MaxLR=3e-04','WU=0.0 MaxLR=1.5e-04',
                        'WU=0.0 MaxLR=6e-04',
                        '27000','10000','scratch'
                       ],
                upper_limit=300,
                key_to_plot='validation/val_0/lm_loss',
                ylabel='Pile Val PPL (upstream)',
                xlabel='SlimPajama Val PPL (downstream)',
                savepath="wu=0.01-pile-RP-val-loss-RP-models-300B.pdf",
                legend_kwargs=dict(fontsize=11,loc="lower right"),
                ylim=(2.18,2.55),
                figsize=(7.5,5),
                warmup_end={'0.01':True,'0.02':True,'0.005':True},
                skip=20,
                cmap_label='Tokens (B)',
            key_map={x:get_caption(x,use=dict(mx=True,wu=False,mn=False,ds=False,it=False)) \
                        for x in rd_clone.keys()}
#                key_map={
#                    "WU=0.0 MaxLR=3e-05 MinLR=3e-05 RP": "3e-05 Constant WU=0.0",
#                    "WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 RP": "1.5e-04 consine WU=0.01",
#                     "WU=0.01 MaxLR=3e-04 MinLR=3e-05 RP": "3e-04 consine WU=0.01",
#                     "WU=0.01 MaxLR=6e-04 MinLR=6e-05 RP": "6e-04 cosine WU=0.01",
                   
#                }
               )
# Out:
# "It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B finetune":
# "It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B finetune":
# "It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=pile-train resume":
# "It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B finetune":
# "It=132366 WU=0.01 MaxLR=6e-04 MinLR=6e-05 Sch=cosine Tr=slim-pajama-300B finetune":
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [45], in <cell line: 1>()
# ----> 1 plot_with_cmap(filter_=['WU=0.005','WU=0.02','Pile',
#       2                         'WU=0.0 MaxLR=3e-04','WU=0.0 MaxLR=1.5e-04',
#       3                         'WU=0.0 MaxLR=6e-04',
#       4                         '27000','10000','scratch'
#       5                        ],
#       6                 upper_limit=300,
#       7                 key_to_plot='validation/val_0/lm_loss',
#       8                 ylabel='Pile Val PPL (upstream)',
#       9                 xlabel='SlimPajama Val PPL (downstream)',
#      10                 savepath="wu=0.01-pile-RP-val-loss-RP-models-300B.pdf",
#      11                 legend_kwargs=dict(fontsize=11,loc="lower right"),
#      12                 ylim=(2.18,2.55),
#      13                 figsize=(7.5,5),
#      14                 warmup_end={'0.01':True,'0.02':True,'0.005':True},
#      15                 skip=20,
#      16                 cmap_label='Tokens (B)',
#      17             key_map={x:get_caption(x,use=dict(mx=True,wu=False,mn=False,ds=False,it=False)) \
#      18                         for x in rd_clone.keys()}
#      19 #                key_map={
#      20 #                    "WU=0.0 MaxLR=3e-05 MinLR=3e-05 RP": "3e-05 Constant WU=0.0",
#      21 #                    "WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 RP": "1.5e-04 consine WU=0.01",
#      22 #                     "WU=0.01 MaxLR=3e-04 MinLR=3e-05 RP": "3e-04 consine WU=0.01",
#      23 #                     "WU=0.01 MaxLR=6e-04 MinLR=6e-05 RP": "6e-04 cosine WU=0.01",
#      24
#      25 #                }
#      26                )
#
# Input In [40], in plot_with_cmap(filter_, upper_limit, key_to_plot, ylabel, xlabel, savepath, legend_kwargs, ylim, figsize, warmup_end, skip, cmap_label, key_map, savedir)
#      95 sm.set_label(cmap_label)
#      96 if savepath:
# ---> 97     plt.savefig(savedir+savepath,bbox_inches='tight')
#      98     savepath = savepath[:-4] + '.png'
#      99     plt.savefig(savedir+savepath,bbox_inches='tight')
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:958, in savefig(*args, **kwargs)
#     955 @_copy_docstring_and_deprecators(Figure.savefig)
#     956 def savefig(*args, **kwargs):
#     957     fig = gcf()
# --> 958     res = fig.savefig(*args, **kwargs)
#     959     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     960     return res
#
# File ~\anaconda3\lib\site-packages\matplotlib\figure.py:3019, in Figure.savefig(self, fname, transparent, **kwargs)
#    3015     for ax in self.axes:
#    3016         stack.enter_context(
#    3017             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3019 self.canvas.print_figure(fname, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py:2319, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2315 try:
#    2316     # _get_renderer may change the figure dpi (as vector formats
#    2317     # force the figure dpi to 72), so we need to set it again here.
#    2318     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319         result = print_method(
#    2320             filename,
#    2321             facecolor=facecolor,
#    2322             edgecolor=edgecolor,
#    2323             orientation=orientation,
#    2324             bbox_inches_restore=_bbox_inches_restore,
#    2325             **kwargs)
#    2326 finally:
#    2327     if bbox_inches and restore_bbox:
#
# File ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py:1648, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1640     _api.warn_deprecated(
#    1641         '3.3', name=name, removal='3.6',
#    1642         message='%(name)s() got unexpected keyword argument "'
#    1643                 + arg + '" which is no longer supported as of '
#    1644                 '%(since)s and will become an error '
#    1645                 '%(removal)s')
#    1646     kwargs.pop(arg)
# -> 1648 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py:386, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     381 @functools.wraps(func)
#     382 def wrapper(*inner_args, **inner_kwargs):
#     383     if len(inner_args) <= name_idx and name not in inner_kwargs:
#     384         # Early return in the simple, non-deprecated case (much faster than
#     385         # calling bind()).
# --> 386         return func(*inner_args, **inner_kwargs)
#     387     arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     388     if is_varargs and arguments.get(name):
#
# File ~\anaconda3\lib\site-packages\matplotlib\backends\backend_pdf.py:2778, in FigureCanvasPdf.print_pdf(self, filename, dpi, bbox_inches_restore, metadata)
#    2776     file = filename._file
#    2777 else:
# -> 2778     file = PdfFile(filename, metadata=metadata)
#    2779 try:
#    2780     file.newPage(width, height)
#
# File ~\anaconda3\lib\site-packages\matplotlib\backends\backend_pdf.py:654, in PdfFile.__init__(self, filename, metadata)
#     652 self.original_file_like = None
#     653 self.tell_base = 0
# --> 654 fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#     655 if not opened:
#     656     try:
#
# File ~\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:451, in to_filehandle(fname, flag, return_opened, encoding)
#     449         fh = bz2.BZ2File(fname, flag)
#     450     else:
# --> 451         fh = open(fname, flag, encoding=encoding)
#     452     opened = True
#     453 elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'esfomows/wu=0.01-pile-RP-val-loss-RP-models-300B.pdf'

# %%
plot_with_cmap(filter_=['WU=0.005','WU=0.02','Pile',
                        'WU=0.0 MaxLR=3e-04','WU=0.0 MaxLR=1.5e-04',
                        'WU=0.0 MaxLR=6e-04',
                        '27000','10000','scratch'
                       ],
                upper_limit=240,
                key_to_plot='validation/val_0/lm_loss',
                ylabel='Pile Val PPL (upstream)',
                xlabel='SlimPajama Val PPL (downstream)',
                savepath="wu=0.01-pile-RP-val-loss-RP-models-240B.pdf",
                legend_kwargs=dict(fontsize=11,loc="lower right"),
                ylim=(2.18,2.55),
                figsize=(7.5,5),
                warmup_end={'0.01':True,'0.02':True,'0.005':True},
                skip=20,
                cmap_label='Tokens (B)',
            key_map={x:get_caption(x,use=dict(mx=True,wu=False,mn=False,ds=False,it=False)) \
                        for x in rd_clone.keys()}
#                key_map={
#                    "WU=0.0 MaxLR=3e-05 MinLR=3e-05 RP": "3e-05 Constant WU=0.0",
#                    "WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 RP": "1.5e-04 consine WU=0.01",
#                     "WU=0.01 MaxLR=3e-04 MinLR=3e-05 RP": "3e-04 consine WU=0.01",
#                     "WU=0.01 MaxLR=6e-04 MinLR=6e-05 RP": "6e-04 cosine WU=0.01",
                   
#                }
               )
# Out:
# "It=132366 WU=0.0 MaxLR=3e-05 MinLR=3e-05 Sch=constant Tr=slim-pajama-300B finetune":
# "It=132366 WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 Sch=cosine Tr=slim-pajama-300B finetune":
# "It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=pile-train resume":
# "It=132366 WU=0.01 MaxLR=3e-04 MinLR=3e-05 Sch=cosine Tr=slim-pajama-300B finetune":
# "It=132366 WU=0.01 MaxLR=6e-04 MinLR=6e-05 Sch=cosine Tr=slim-pajama-300B finetune":
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 plot_with_cmap(filter_=['WU=0.005','WU=0.02','Pile',
#       2                         'WU=0.0 MaxLR=3e-04','WU=0.0 MaxLR=1.5e-04',
#       3                         'WU=0.0 MaxLR=6e-04',
#       4                         '27000','10000','scratch'
#       5                        ],
#       6                 upper_limit=240,
#       7                 key_to_plot='validation/val_0/lm_loss',
#       8                 ylabel='Pile Val PPL (upstream)',
#       9                 xlabel='SlimPajama Val PPL (downstream)',
#      10                 savepath="wu=0.01-pile-RP-val-loss-RP-models-240B.pdf",
#      11                 legend_kwargs=dict(fontsize=11,loc="lower right"),
#      12                 ylim=(2.18,2.55),
#      13                 figsize=(7.5,5),
#      14                 warmup_end={'0.01':True,'0.02':True,'0.005':True},
#      15                 skip=20,
#      16                 cmap_label='Tokens (B)',
#      17             key_map={x:get_caption(x,use=dict(mx=True,wu=False,mn=False,ds=False,it=False)) \
#      18                         for x in rd_clone.keys()}
#      19 #                key_map={
#      20 #                    "WU=0.0 MaxLR=3e-05 MinLR=3e-05 RP": "3e-05 Constant WU=0.0",
#      21 #                    "WU=0.01 MaxLR=1.5e-04 MinLR=1.5e-05 RP": "1.5e-04 consine WU=0.01",
#      22 #                     "WU=0.01 MaxLR=3e-04 MinLR=3e-05 RP": "3e-04 consine WU=0.01",
#      23 #                     "WU=0.01 MaxLR=6e-04 MinLR=6e-05 RP": "6e-04 cosine WU=0.01",
#      24
#      25 #                }
#      26                )
#
# Input In [40], in plot_with_cmap(filter_, upper_limit, key_to_plot, ylabel, xlabel, savepath, legend_kwargs, ylim, figsize, warmup_end, skip, cmap_label, key_map, savedir)
#      95 sm.set_label(cmap_label)
#      96 if savepath:
# ---> 97     plt.savefig(savedir+savepath,bbox_inches='tight')
#      98     savepath = savepath[:-4] + '.png'
#      99     plt.savefig(savedir+savepath,bbox_inches='tight')
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:958, in savefig(*args, **kwargs)
#     955 @_copy_docstring_and_deprecators(Figure.savefig)
#     956 def savefig(*args, **kwargs):
#     957     fig = gcf()
# --> 958     res = fig.savefig(*args, **kwargs)
#     959     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     960     return res
#
# File ~\anaconda3\lib\site-packages\matplotlib\figure.py:3019, in Figure.savefig(self, fname, transparent, **kwargs)
#    3015     for ax in self.axes:
#    3016         stack.enter_context(
#    3017             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3019 self.canvas.print_figure(fname, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py:2319, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2315 try:
#    2316     # _get_renderer may change the figure dpi (as vector formats
#    2317     # force the figure dpi to 72), so we need to set it again here.
#    2318     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319         result = print_method(
#    2320             filename,
#    2321             facecolor=facecolor,
#    2322             edgecolor=edgecolor,
#    2323             orientation=orientation,
#    2324             bbox_inches_restore=_bbox_inches_restore,
#    2325             **kwargs)
#    2326 finally:
#    2327     if bbox_inches and restore_bbox:
#
# File ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py:1648, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1640     _api.warn_deprecated(
#    1641         '3.3', name=name, removal='3.6',
#    1642         message='%(name)s() got unexpected keyword argument "'
#    1643                 + arg + '" which is no longer supported as of '
#    1644                 '%(since)s and will become an error '
#    1645                 '%(removal)s')
#    1646     kwargs.pop(arg)
# -> 1648 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py:386, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     381 @functools.wraps(func)
#     382 def wrapper(*inner_args, **inner_kwargs):
#     383     if len(inner_args) <= name_idx and name not in inner_kwargs:
#     384         # Early return in the simple, non-deprecated case (much faster than
#     385         # calling bind()).
# --> 386         return func(*inner_args, **inner_kwargs)
#     387     arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     388     if is_varargs and arguments.get(name):
#
# File ~\anaconda3\lib\site-packages\matplotlib\backends\backend_pdf.py:2778, in FigureCanvasPdf.print_pdf(self, filename, dpi, bbox_inches_restore, metadata)
#    2776     file = filename._file
#    2777 else:
# -> 2778     file = PdfFile(filename, metadata=metadata)
#    2779 try:
#    2780     file.newPage(width, height)
#
# File ~\anaconda3\lib\site-packages\matplotlib\backends\backend_pdf.py:654, in PdfFile.__init__(self, filename, metadata)
#     652 self.original_file_like = None
#     653 self.tell_base = 0
# --> 654 fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#     655 if not opened:
#     656     try:
#
# File ~\anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:451, in to_filehandle(fname, flag, return_opened, encoding)
#     449         fh = bz2.BZ2File(fname, flag)
#     450     else:
# --> 451         fh = open(fname, flag, encoding=encoding)
#     452     opened = True
#     453 elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'esfomows/wu=0.01-pile-RP-val-loss-RP-models-240B.pdf'
